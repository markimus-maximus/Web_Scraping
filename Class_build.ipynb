# %%
import requests
import ast
from bs4 import  BeautifulSoup
from datetime import date, datetime
import pandas as pd
import datetime
from datetime import timedelta, date
from selenium import webdriver
from selenium.webdriver.common.by import By
import os
import json
import urllib.request
from pathlib import Path
import uuid

# %%
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)
global list_dates
permalink_list = []
url_list = []
start_date = date(2013, 4, 28)
end_date = date(2022, 7, 3)
for single_date in daterange(start_date, end_date):

    list = str(single_date.strftime("%Y%m%d/"))
   
    permalink_list.append(list)

print(permalink_list)
# Out:
# ['20130428/', '20130429/', '20130430/', '20130501/', '20130502/', '20130503/', '20130504/', '20130505/', '20130506/', '20130507/', '20130508/', '20130509/', '20130510/', '20130511/', '20130512/', '20130513/', '20130514/', '20130515/', '20130516/', '20130517/', '20130518/', '20130519/', '20130520/', '20130521/', '20130522/', '20130523/', '20130524/', '20130525/', '20130526/', '20130527/', '20130528/', '20130529/', '20130530/', '20130531/', '20130601/', '20130602/', '20130603/', '20130604/', '20130605/', '20130606/', '20130607/', '20130608/', '20130609/', '20130610/', '20130611/', '20130612/', '20130613/', '20130614/', '20130615/', '20130616/', '20130617/', '20130618/', '20130619/', '20130620/', '20130621/', '20130622/', '20130623/', '20130624/', '20130625/', '20130626/', '20130627/', '20130628/', '20130629/', '20130630/', '20130701/', '20130702/', '20130703/', '20130704/', '20130705/', '20130706/', '20130707/', '20130708/', '20130709/', '20130710/', '20130711/', '20130712/', '20130713/', '20130714/', '20130715/', '20130716/', '20130717/', '20130718/', '20130719/', '20130720/', '20130721/', '20130722/', '20130723/', '20130724/', '20130725/', '20130726/', '20130727/', '20130728/', '20130729/', '20130730/', '20130731/', '20130801/', '20130802/', '20130803/', '20130804/', '20130805/', '20130806/', '20130807/', '20130808/', '20130809/', '20130810/', '20130811/', '20130812/', '20130813/', '20130814/', '20130815/', '20130816/', '20130817/', '20130818/', '20130819/', '20130820/', '20130821/', '20130822/', '20130823/', '20130824/', '20130825/', '20130826/', '20130827/', '20130828/', '20130829/', '20130830/', '20130831/', '20130901/', '20130902/', '20130903/', '20130904/', '20130905/', '20130906/', '20130907/', '20130908/', '20130909/', '20130910/', '20130911/', '20130912/', '20130913/', '20130914/', '20130915/', '20130916/', '20130917/', '20130918/', '20130919/', '20130920/', '20130921/', '20130922/', '20130923/', '20130924/', '20130925/', '20130926/', '20130927/', '20130928/', '20130929/', '20130930/', '20131001/', '20131002/', '20131003/', '20131004/', '20131005/', '20131006/', '20131007/', '20131008/', '20131009/', '20131010/', '20131011/', '20131012/', '20131013/', '20131014/', '20131015/', '20131016/', '20131017/', '20131018/', '20131019/', '20131020/', '20131021/', '20131022/', '20131023/', '20131024/', '20131025/', '20131026/', '20131027/', '20131028/', '20131029/', '20131030/', '20131031/', '20131101/', '20131102/', '20131103/', '20131104/', '20131105/', '20131106/', '20131107/', '20131108/', '20131109/', '20131110/', '20131111/', '20131112/', '20131113/', '20131114/', '20131115/', '20131116/', '20131117/', '20131118/', '20131119/', '20131120/', '20131121/', '20131122/', '20131123/', '20131124/', '20131125/', '20131126/', '20131127/', '20131128/', '20131129/', '20131130/', '20131201/', '20131202/', '20131203/', '20131204/', '20131205/', '20131206/', '20131207/', '20131208/', '20131209/', '20131210/', '20131211/', '20131212/', '20131213/', '20131214/', '20131215/', '20131216/', '20131217/', '20131218/', '20131219/', '20131220/', '20131221/', '20131222/', '20131223/', '20131224/', '20131225/', '20131226/', '20131227/', '20131228/', '20131229/', '20131230/', '20131231/', '20140101/', '20140102/', '20140103/', '20140104/', '20140105/', '20140106/', '20140107/', '20140108/', '20140109/', '20140110/', '20140111/', '20140112/', '20140113/', '20140114/', '20140115/', '20140116/', '20140117/', '20140118/', '20140119/', '20140120/', '20140121/', '20140122/', '20140123/', '20140124/', '20140125/', '20140126/', '20140127/', '20140128/', '20140129/', '20140130/', '20140131/', '20140201/', '20140202/', '20140203/', '20140204/', '20140205/', '20140206/', '20140207/', '20140208/', '20140209/', '20140210/', '20140211/', '20140212/', '20140213/', '20140214/', '20140215/', '20140216/', '20140217/', '20140218/', '20140219/', '20140220/', '20140221/', '20140222/', '20140223/', '20140224/', '20140225/', '20140226/', '20140227/', '20140228/', '2014030 ...

# %%
from time import strptime


class Scraper: 
    
    def __init__(self):
        import requests
        import ast
        from bs4 import  BeautifulSoup
        import time
        import pandas as pd
        from datetime import timedelta, date
        from selenium import webdriver
        from selenium.webdriver.common.by import By
        import os
        import json
        import urllib.request
        from pathlib import Path

        self.permalink_list = []
    
        self.url_list = []

        self.uuid_list = []
    
        self.record_uuid_dict = {}

    
        self.crypto_name_list = []
    
        self.crypto_market_cap_list = []

        self.crypto_price_list = []
    
    
        self.crypto_circulating_supply_list = []


        self.crypto_ticker_list = []
    

        self.daily_records_combined_list = []
       
        self.combined_lists = []
     

    def webdriver_init(self, url):
        ''' webdriver_init(url) 
        url = the url to access using the webdriver
        function for initialising webdriver and requesting url. This saves repeating code in the subsequent methods, and 
        # streamlines declaring url variable to one method. '''

        driver = webdriver.Chrome('C:\\Users\\marko\\chromedriver.exe')
        request = driver.get(url)
        time.sleep(2) # Delay to avoid looking like a bot to server
    
    
       

    
     

    def create_url_list_with_date_permalinks(self, permalink_list, root_url):
        '''create_url_list_with_date_permalinks(list, root_url)
        permalink_list = list of permalinks to concatenate to root url
        root_url = the url root address with which to concatenate the permalink list
        function for concatenating list of permalinks to given url, returning a list of unique urls containing url and permalink.
            the list attribute is the pre-made list of url permalinks (e.g. date_list from daterange function). Furthermore, this 
            function creates a uuid for each unique iteration in the list'''
       
        
        
        for url_extension in permalink_list:
            #concatenate the root_url with the url permalink
            url_instance = root_url + str(url_extension)
            url_list.append(url_instance)
        
        self.url_list = self.url_list[::7]
        print(self.url_list)

   
    
    def UUID_dictionary(self, record_list):
        ''' UUID_dictionary(record_list)
        record_list = the list of records which are to be concatenated to UUIDs
        This method generates UUIDs for every record in the method attribute list. This UUID is then
        stored in a list. This function then takes other lists of interest to generate a dictionary
        including the UUID and the record of interest. Record_list_1 can be the defining
        feautre such as the webpage url or date of the record.  The dictionary
        is then converted to a JSON file and saved in a folder'''

        
        #generate a pseudo-unique uuid for every record in the list by taking the length of the list
        for UUID in range(len(record_list)):
            #generates 1 uuid4 and converts to string (this is easier for dictionary saving to JSON)
            single_uuid = str(uuid.uuid4())
            #append the UUID to the list
            self.uuid_list.append(single_uuid)
        #making the dictionary with the record list and the uuid list just generated
        
        record_uuid_dict = dict(zip(self.uuid_list, record_list))
        
        x = record_uuid_dict.keys()
        print(x)
        print(record_uuid_dict)
        
    def make_dictionary_into_json_and_save(self): 
        '''make_dictionary_into_json_and_save(self)
        This method converts dictionary into json file and saves it.''' 
    #make a folder if the folder doesn't exist
        if not os.path.exists('raw_data'):
            os.makedirs('raw_data')
       
       #make json data file if it doesn't already exist
        
        json.dump(record_uuid_dict, fp)
        # moving the json file to a different directory- is there a more efficient way of doing this?
        Path(r"C:\Users\marko\Desktop\Web_Scraping\data.json").rename(r"C:\Users\marko\Desktop\Web_Scraping\raw_data\data.json")

        
    

        
   

    def get_image_list_from_webpage(self, url):
        '''get_image_list_from_webpage(url) 
        url = the url of the website to scape
        This method gets all image src from attribute webpage and appends to a list'''
    #define url and vary permalink depending on the date
        
        
        #request webpage
        webpage = requests.get(url)
        
        #parse the html
        soup = BeautifulSoup(webpage.text, 'html.parser')

        #create a variable for the table rows (tr)
        images = soup.find_all('img')
        #create image list
        image_list = []
        # iterate through every src and extract only the src text
        for image in images:
            #strips the src url only
            image = image['src']
            #appends stripped url to list
            image_list.append(image)
        print(image_list)

    
        def page_click_and_count(self, num_pages, next__page_button_XPath):
            '''
            page_click_and_count(num_pages, next_button_XPath)
            num_pages = number of pages to click before method ends
            next_page_button_XPath = XPath of next page button
            method to click through set number of pages (num_pages) by clicking on an allocated 'next page' button XPath 
            useful funtion to integrate into code for webscraping'''
            page_click_counter = 0
            #creating while loop to click a certain number of pages
            while (page_click_counter < num_pages):
                count = 0
                next_week_button = driver.find_element(by=By.XPATH, value= 'next_week_button_XPath')
                
                next_week_button.click()
                
                print('button_clicked')

                page_click_counter += 1 
   

    


    def save_images_from_webpage(self):
        '''save_images_from_webpage()
        saves an image in a particular file, NEED TO WORK OUT WHY CAN'T SET DIRECTORY TO THE BELOW 
        NOMINATED FOLDER AS OPPOSED TO DEFAU;LT PATH'''

        urllib.request.urlretrieve('https://s2.coinmarketcap.com/static/img/coins/32x32/1.png', r"C:\Users\marko\Desktop\Web_Scraping\Web pictures.jpg")
        



    def cookies_bypass(self, XPath):
        '''cookies_bypass(XPath)
        XPath = XPath for clicking cookies bypass
        method for bypassing cookies by clicking accept cookies button'''

        time.sleep(2) # Delay to avoid looking like a bot to server

        try: 
            accept_cookies_button = driver.find_element(by=By.XPATH, value= XPath)
            accept_cookies_button.click()

        except: pass

  

    def auto_login(self, email_address, password):
        '''  auto_login(email_address, password)
        email_address = login email
        password = login password
        method for logging into webpage'''
        
        # input the username string
        XPath_email_field = input('What is the XPath for inputting email_address?')
        username = driver.find_element(by=By.XPATH, value= XPath_email_field)
        username.send_keys(email_address)

        # click continue to send username 
        XPath_click_conitnue_login = input('What is the XPath for pressing continue?')
        username_send_click = driver.find_element(by=By.XPATH, value= XPath_click_conitnue_login)
        username_send_click.click()

        #input the password string
        XPath_input_password = input('What is the XPath for inputting password?')
        password = driver.find_element(by=By.XPATH, value= XPath_input_password)
        password.send_keys("password")

        #click continue to send password
        XPath_click_login = input('What is the XPath for clicking login?')
        password_send_click = driver.find_element(by=By.XPATH, value= XPath_click_login)
        password_send_click.click()


    def scroll_page(self, x, y):
        '''scroll_page(x, y)
        x = x coordinate to scroll to
        y = y coordinate to scroll to
        This method scrolls a webpage using selenium. Input the url, and the x,y coordinaytes for the 
    #location to scroll to. Simply scrolling down would leave x as 0. A full HD monitor is 1080 in the y
    #plane, so to scroll to the bottom would be (0,1080)'''

        driver.execute_script("window.scrollTo({},{}).".format(x,y))

        time.sleep(2) # Delay to avoid looking like a bot to server

        scroll_page(url)

    #code for clicking off notification alert (:2 is diable notifications)
    
    def click_notifications():
        '''click_notifications()
        0 arguments required
        Method to click not to accept notifications'''
        chrome_options = webdriver.ChromeOptions()
        prefs = {"profile.default_content_setting_values.notifications" : 2}
        chrome_options.add_experimental_option("prefs",prefs)
        driver = webdriver.Chrome(chrome_options=chrome_options)

## link the daily scraped data below to theurl and dictionary

     #creating empty lists with which to store many days of data. Item_limit = number of cyptocurrencies
     #to scrape. num_pages is the number of webpages to go though
    def scrape_crypto_rows(self, daily_item_limit, num_pages):
            '''crypto_scrape_get_crypto_rows(daily_item_limit, num_pages)
            Requires 2 arguments
            Item_limit = number of cyptocurrencies to scrape per day 
            num_pages = number of webpages to iterate through
            This function scrapes each row of data correlating to the associated bitcoin. For example, this could be
            Bitcoin data from a particular page (date). Two parameters are required: '''
#creating empty lists with which to store  all of the weekly data
            

              #creating lists to store the weekly data (one day a week)
            crypto_name_list_one_day = []
            crypto_market_cap_list_one_day = []
            crypto_price_list_one_day = []
            crypto_circulating_supply_list_one_day = []
            crypto_ticker_list_one_day = []

            #creating lists for each daily entry
           


            for url in url_list[:num_pages]:

             
            #creating a data frame for later
                df = pd.DataFrame()
            
                #request webpage
                webpage = requests.get(url)
            
                #parse the html
                soup = BeautifulSoup(webpage.text, 'html.parser')
        
      

        
            
                

            

                #create a variable for the table rows (tr), limited to the first 10, this can be changed to anything with attribute
                self.tr = soup.find_all('tr', attrs={'class':'cmc-table-row'})
                #The number of records per page, useful for scraping all records 
                self.tr_length = len(self.tr)
                print(self.tr_length)
                #call the function iteratively
                self.scrape_items_from_row()
                

    def scrape_items_from_row(self):   
        ''' scrape_item_from_row()
        Requires 0 arguments 
    This function scrapes the data from one of the cryptocurrency rows generated in the  function 'crypto_scrape_get_crypto_rows'. 
    In this function, the crypto name, price, ticker, market cap and circulating supply are stored in individual lists. Each value, 
    for example price, is stored in a list of each of the cryptocurrencies from that day. For example, all of the names of cryptocurrencies
    scraped from a particular webpage (corresponding to a particular date) would be contained in the list crypto_name_list. Finally, all of 
    the daily data is concatenated to others days of data and matched by list index
        '''    
        count = 0
        for row in self.tr:
    #store the name of the coin as a variable by finding td element (column) 
            name_column = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sticky cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--sort-by__name'})
            if name_column == None:
                break
            #find the column within the row and strip the text
            crypto_name = name_column.find('a', attrs={'class': 'cmc-table__column-name--name cmc-link'}).text.strip()
            print(crypto_name)

            #find and createvvariable for market cap
            crypto_market_cap = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__market-cap'}).text.strip()
            print(crypto_market_cap)

            #Find and create variable for the price
            crypto_price = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__price'}).text.strip()
            print(crypto_price)
            #Find and create variable for the circulating supply
            crypto_circulating_supply_and_ticker = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__circulating-supply'}).text.strip()
            print(crypto_circulating_supply_and_ticker)
            #Find and create variable for the circulating supply by splitting the supply+ticker variable
            crypto_ticker = crypto_circulating_supply_and_ticker.split(' ')[1]
            print(crypto_ticker)
            #Find and create variable for the coin ticker
            crypto_circulating_supply = crypto_circulating_supply_and_ticker.split(' ')[0]
            print(crypto_circulating_supply)
            

            #append the data to the associated lists
            self.crypto_name_list.append(crypto_name)
            
            self.crypto_market_cap_list.append(crypto_market_cap)
            self.crypto_price_list.append(crypto_price)
            self.crypto_circulating_supply_list.append(crypto_circulating_supply)
            self.crypto_ticker_list.append(crypto_ticker)
            # increase the counter for appending rows within 1 day   

            count += 1
            if count == self.tr_length:
                break
            
        
        print(len(self.crypto_name_list))
        print(len(self.crypto_circulating_supply_list))
        print(len(self.crypto_market_cap_list))
        print(len(self.crypto_price_list))
        print(len(self.crypto_ticker_list))
        print(self.crypto_name_list)   
        

        #this code packages each record into a list: for example BTC price from a particular date. These lists can then be added to a 
        # dictionary. This function could be broadly applicable to any collection of lists which yield corresponding data from the same index
            
        for i in range(len(self.crypto_name_list)):
            self.daily_records_combined_list.append([self.crypto_name_list[i],self.crypto_market_cap_list[i],self.crypto_price_list[i],self.crypto_circulating_supply_list[i],self.crypto_ticker_list[i]])  
        print(self.daily_records_combined_list)

   
   
    def list_zipper(self, shortest_list, List_1, List_2): 
        '''list_zipper(shortest_list, List_1, List_2)
        Requires 3 arguments
        shortest_list = the list with the shortest number of indices (prevents out of range error), 
        List 1 = one of the lists to append 
        List 2 = the second list to be appended together
        This function appends 2 lists together based on the length on the shortest list according to the index of the list'''
        
        
        for i in range(len(shortest_list)):
            self.combined_lists.append([List_1[i], List_2[i]])
        
        print(self.combined_lists)



    
    
            
               

            
                
            
                
    





if __name__ =="__main__":
    Scraper()

# %%
yolo = Scraper()
yolo.create_url_list_with_date_permalinks(list_dates, 'https://coinmarketcap.com/historical/')
yolo.scrape_crypto_rows(10, 20)
#yolo.UUID_dictionary(url_list)
yolo.list_zipper(yolo.daily_records_combined_list, yolo.daily_records_combined_list, url_list)
        




    

    

    
     



## link the daily scraped data below to the url and dictionary
# Out:
# []
# 7
# Bitcoin
# $1,488,566,971.96
# $134.21
# 11,091,325 BTC
# BTC
# 11,091,325
# Litecoin
# $74,637,021.57
# $4.35
# 17,164,230 LTC
# LTC
# 17,164,230
# Peercoin
# $7,250,186.65
# $0.3865
# 18,757,362 PPC
# PPC
# 18,757,362
# Namecoin
# $5,995,997.19
# $1.11
# 5,415,300 NMC
# NMC
# 5,415,300
# Terracoin
# $1,503,099.40
# $0.6469
# 2,323,570 TRC
# TRC
# 2,323,570
# Devcoin
# $1,424,087.30
# $0.0003261
# 4,366,620,160 DVC
# DVC
# 4,366,620,160
# Novacoin
# $1,162,266.30
# $4.25
# 273,706 NVC
# NVC
# 273,706
# 7
# 7
# 7
# 7
# 7
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin']
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC']]
# 7
# Bitcoin
# $1,603,768,790.01
# $144.54
# 11,095,675 BTC
# BTC
# 11,095,675
# Litecoin
# $75,388,933.89
# $4.38
# 17,196,780 LTC
# LTC
# 17,196,780
# Peercoin
# $7,673,907.76
# $0.4089
# 18,769,008 PPC
# PPC
# 18,769,008
# Namecoin
# $7,204,954.88
# $1.33
# 5,424,100 NMC
# NMC
# 5,424,100
# Terracoin
# $1,657,022.80
# $0.7097
# 2,334,850 TRC
# TRC
# 2,334,850
# Devcoin
# $1,636,609.70
# $0.0003744
# 4,371,769,856 DVC
# DVC
# 4,371,769,856
# Novacoin
# $1,278,294.60
# $4.67
# 273,974 NVC
# NVC
# 273,974
# 14
# 14
# 14
# 14
# 14
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin']
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC']]
# 7
# Bitcoin
# $1,542,813,463.73
# $139.00
# 11,099,375 BTC
# BTC
# 11,099,375
# Litecoin
# $74,020,937.66
# $4.30
# 17,228,230 LTC
# LTC
# 17,228,230
# Namecoin
# $8,155,721.09
# $1.50
# 5,432,800 NMC
# NMC
# 5,432,800
# Peercoin
# $7,052,668.37
# $0.3753
# 18,792,078 PPC
# PPC
# 18,792,078
# Terracoin
# $1,582,115.67
# $0.6742
# 2,346,830 TRC
# TRC
# 2,346,830
# Devcoin
# $1,491,292.54
# $0.0003406
# 4,379,069,952 DVC
# DVC
# 4,379,069,952
# Novacoin
# $1,183,167.47
# $4.31
# 274,227 NVC
# NVC
# 274,227
# 21
# 21
# 21
# 21
# 21
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin']
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC']]
# 7
# Bitcoin
# $1,298,954,824.16
# $116.99
# 11,103,125 BTC
# BTC
# 11,103,125
# Litecoin
# $65,604,524.58
# $3.80
# 17,259,780 LTC
# LTC
# 17,259,780
# Namecoin
# $6,596,944.24
# $1.21
# 5,437,700 NMC
# NMC
# 5,437,700
# Peercoin
# $6,070,630.05
# $0.3229
# 18,800,780 PPC
# PPC
# 18,800,780
# Terracoin
# $1,340,640.30
# $0.5686
# 2,357,910 TRC
# TRC
# 2,357,910
# Devcoin
# $1,246,015.87
# $0.0002843
# 4,382,969,856 DVC
# DVC
# 4,382,969,856
# Novacoin
# $1,011,229.28
# $3.68
# 274,491 NVC
# NVC
# 274,491
# 28
# 28
# 28
# 28
# 28
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin']
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,298,954,824.16', '$116. ...
# 7
# Bitcoin
# $1,168,517,485.08
# $105.21
# 11,106,525 BTC
# BTC
# 11,106,525
# Litecoin
# $58,287,986.25
# $3.37
# 17,285,980 LTC
# LTC
# 17,285,980
# Namecoin
# $5,812,540.27
# $1.07
# 5,437,700 NMC
# NMC
# 5,437,700
# Peercoin
# $5,244,303.57
# $0.2788
# 18,809,832 PPC
# PPC
# 18,809,832
# Terracoin
# $1,249,943.46
# $0.5271
# 2,371,350 TRC
# TRC
# 2,371,350
# Devcoin
# $1,117,251.33
# $0.0002546
# 4,388,120,064 DVC
# DVC
# 4,388,120,064
# Novacoin
# $905,551.67
# $3.30
# 274,724 NVC
# NVC
# 274,724
# 35
# 35
# 35
# 35
# 35
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin']
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,298,954,824.16', '$116. ...
# 10
# Bitcoin
# $1,085,995,168.75
# $97.75
# 11,109,925 BTC
# BTC
# 11,109,925
# Litecoin
# $52,694,891.66
# $3.04
# 17,305,880 LTC
# LTC
# 17,305,880
# Namecoin
# $4,993,215.93
# $0.9159
# 5,451,600 NMC
# NMC
# 5,451,600
# Peercoin
# $4,947,397.70
# $0.2629
# 18,815,154 PPC
# PPC
# 18,815,154
# Feathercoin
# $2,691,756.67
# $0.4418
# 6,092,250 FTC
# FTC
# 6,092,250
# Freicoin
# $2,252,761.48
# $0.1183
# 19,046,408 FRC
# FRC
# 19,046,408
# Terracoin
# $1,347,010.07
# $0.565
# 2,384,110 TRC
# TRC
# 2,384,110
# Devcoin
# $1,030,837.04
# $0.0002346
# 4,394,019,840 DVC
# DVC
# 4,394,019,840
# Novacoin
# $823,725.21
# $3.00
# 274,938 NVC
# NVC
# 274,938
# Mincoin
# $149,530.13
# $0.1466
# 1,019,813 MNC
# MNC
# 1,019,813
# 45
# 45
# 45
# 45
# 45
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin']
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,298,954,824.16', '$116. ...
# 10
# Bitcoin
# $1,250,316,562.50
# $112.50
# 11,113,925 BTC
# BTC
# 11,113,925
# Litecoin
# $60,290,954.12
# $3.48
# 17,326,854 LTC
# LTC
# 17,326,854
# Namecoin
# $5,765,747.71
# $1.06
# 5,458,050 NMC
# NMC
# 5,458,050
# Peercoin
# $5,611,449.44
# $0.2981
# 18,822,472 PPC
# PPC
# 18,822,472
# Feathercoin
# $2,823,952.43
# $0.45
# 6,275,450 FTC
# FTC
# 6,275,450
# Freicoin
# $1,980,468.03
# $0.1013
# 19,560,178 FRC
# FRC
# 19,560,178
# Terracoin
# $1,428,990.48
# $0.5962
# 2,396,630 TRC
# TRC
# 2,396,630
# Devcoin
# $1,197,959.97
# $0.0002723
# 4,400,220,160 DVC
# DVC
# 4,400,220,160
# Novacoin
# $959,422.35
# $3.49
# 275,103 NVC
# NVC
# 275,103
# Mincoin
# $299,107.19
# $0.2927
# 1,021,763 MNC
# MNC
# 1,021,763
# 55
# 55
# 55
# 55
# 55
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin']
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,298,954,824.16', '$116. ...
# 10
# Bitcoin
# $1,288,693,216.22
# $115.91
# 11,118,050 BTC
# BTC
# 11,118,050
# Litecoin
# $62,298,217.32
# $3.59
# 17,348,954 LTC
# LTC
# 17,348,954
# Namecoin
# $6,290,543.05
# $1.15
# 5,465,350 NMC
# NMC
# 5,465,350
# Peercoin
# $5,718,446.46
# $0.3037
# 18,830,240 PPC
# PPC
# 18,830,240
# Feathercoin
# $2,017,436.23
# $0.313
# 6,444,650 FTC
# FTC
# 6,444,650
# Freicoin
# $1,627,438.51
# $0.08114
# 20,057,908 FRC
# FRC
# 20,057,908
# Terracoin
# $1,367,162.39
# $0.568
# 2,407,150 TRC
# TRC
# 2,407,150
# Devcoin
# $1,052,081.53
# $0.0002388
# 4,406,170,112 DVC
# DVC
# 4,406,170,112
# Novacoin
# $1,015,804.46
# $3.69
# 275,503 NVC
# NVC
# 275,503
# Mincoin
# $118,657.23
# $0.1159
# 1,023,701 MNC
# MNC
# 1,023,701
# 65
# 65
# 65
# 65
# 65
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin']
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,298,954,824.16', '$116. ...
# 10
# Bitcoin
# $1,249,023,178.80
# $112.30
# 11,122,200 BTC
# BTC
# 11,122,200
# Litecoin
# $58,594,297.59
# $3.37
# 17,380,604 LTC
# LTC
# 17,380,604
# Namecoin
# $5,377,759.60
# $0.9826
# 5,472,850 NMC
# NMC
# 5,472,850
# Peercoin
# $4,654,595.87
# $0.2471
# 18,839,940 PPC
# PPC
# 18,839,940
# Freicoin
# $1,491,232.46
# $0.07288
# 20,460,718 FRC
# FRC
# 20,460,718
# Feathercoin
# $1,166,240.12
# $0.1797
# 6,490,650 FTC
# FTC
# 6,490,650
# Terracoin
# $1,052,199.43
# $0.4346
# 2,421,070 TRC
# TRC
# 2,421,070
# Devcoin
# $921,876.90
# $0.0002089
# 4,413,470,208 DVC
# DVC
# 4,413,470,208
# Novacoin
# $903,417.33
# $3.28
# 275,691 NVC
# NVC
# 275,691
# Mincoin
# $216,880.39
# $0.2111
# 1,027,265 MNC
# MNC
# 1,027,265
# 75
# 75
# 75
# 75
# 75
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Freicoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin']
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,298,954,824.16', '$116. ...
# 10
# Bitcoin
# $1,240,593,600.00
# $111.50
# 11,126,400 BTC
# BTC
# 11,126,400
# Litecoin
# $58,051,179.02
# $3.33
# 17,418,480 LTC
# LTC
# 17,418,480
# Namecoin
# $5,248,949.19
# $0.9578
# 5,480,300 NMC
# NMC
# 5,480,300
# Peercoin
# $4,644,000.74
# $0.2464
# 18,846,258 PPC
# PPC
# 18,846,258
# Feathercoin
# $1,428,566.46
# $0.2197
# 6,503,650 FTC
# FTC
# 6,503,650
# Freicoin
# $1,388,722.91
# $0.0669
# 20,758,190 FRC
# FRC
# 20,758,190
# Terracoin
# $1,069,715.38
# $0.4393
# 2,434,990 TRC
# TRC
# 2,434,990
# Devcoin
# $916,750.91
# $0.0002074
# 4,420,420,096 DVC
# DVC
# 4,420,420,096
# Novacoin
# $908,855.92
# $3.29
# 276,124 NVC
# NVC
# 276,124
# Mincoin
# $218,272.74
# $0.2119
# 1,030,317 MNC
# MNC
# 1,030,317
# 85
# 85
# 85
# 85
# 85
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Freicoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin']
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,298,954,824.16', '$116. ...
# 13
# Bitcoin
# $1,264,044,297.90
# $113.57
# 11,130,525 BTC
# BTC
# 11,130,525
# Litecoin
# $59,508,182.85
# $3.41
# 17,454,980 LTC
# LTC
# 17,454,980
# Peercoin
# $5,503,786.79
# $0.2919
# 18,857,400 PPC
# PPC
# 18,857,400
# Namecoin
# $5,191,133.80
# $0.946
# 5,487,450 NMC
# NMC
# 5,487,450
# Feathercoin
# $1,457,251.20
# $0.2238
# 6,512,450 FTC
# FTC
# 6,512,450
# Freicoin
# $1,180,288.65
# $0.05678
# 20,786,032 FRC
# FRC
# 20,786,032
# Terracoin
# $1,137,830.30
# $0.4645
# 2,449,670 TRC
# TRC
# 2,449,670
# Devcoin
# $1,060,625.59
# $0.0002396
# 4,426,220,032 DVC
# DVC
# 4,426,220,032
# Novacoin
# $971,142.07
# $3.50
# 277,102 NVC
# NVC
# 277,102
# CHNCoin
# $924,392.97
# $0.1862
# 4,963,250 CNC
# CNC
# 4,963,250
# BBQCoin
# $609,322.64
# $0.03634
# 16,766,820 BQC
# BQC
# 16,766,820
# Mincoin
# $234,627.66
# $0.2271
# 1,033,005 MNC
# MNC
# 1,033,005
# Ixcoin
# $178,218.63
# $0.01408
# 12,653,618 IXC *
# IXC
# 12,653,618
# 98
# 98
# 98
# 98
# 98
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Freicoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'CHNCoin', 'BBQCoin', 'Mincoin', 'Ixcoin']
# ...
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,298,954,824.16', '$116. ...
# 14
# Bitcoin
# $1,373,724,130.65
# $123.02
# 11,167,125 BTC
# BTC
# 11,167,125
# Litecoin
# $56,498,056.68
# $3.19
# 17,732,730 LTC
# LTC
# 17,732,730
# Namecoin
# $4,445,869.10
# $0.7984
# 5,568,700 NMC
# NMC
# 5,568,700
# Peercoin
# $4,055,593.78
# $0.214
# 18,947,288 PPC
# PPC
# 18,947,288
# Novacoin
# $1,025,227.76
# $3.64
# 281,465 NVC
# NVC
# 281,465
# Terracoin
# $885,037.06
# $0.3432
# 2,578,690 TRC
# TRC
# 2,578,690
# Devcoin
# $872,250.00
# $0.0001944
# 4,487,719,936 DVC
# DVC
# 4,487,719,936
# Feathercoin
# $831,929.10
# $0.1267
# 6,565,850 FTC
# FTC
# 6,565,850
# Freicoin
# $666,061.93
# $0.03198
# 20,824,910 FRC
# FRC
# 20,824,910
# CHNCoin
# $526,096.32
# $0.1033
# 5,091,290 CNC
# CNC
# 5,091,290
# Mincoin
# $332,209.96
# $0.3144
# 1,056,559 MNC
# MNC
# 1,056,559
# BitBar
# $142,701.03
# $47.73
# 2,990 BTB
# BTB
# 2,990
# BBQCoin
# $136,187.43
# $0.007873
# 17,298,120 BQC
# BQC
# 17,298,120
# Ixcoin
# $129,974.85
# $0.01027
# 12,653,618 IXC *
# IXC
# 12,653,618
# 225
# 225
# 225
# 225
# 225
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Freicoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'CHNCoin', 'BBQCoin', 'Mincoin', 'Ixcoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Freicoin', 'Novacoin', 'CHNCoin', 'BBQCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Devcoin', 'Freicoin', 'Terracoin', 'Novacoin', 'CHNCoin', 'BBQCoin', 'Ixcoin', 'Mincoin', 'BitBar', 'Bytecoin', 'Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Novacoin', 'Devcoin', 'Freicoin', 'Feathercoin', 'CHNCoin', 'Mincoin', 'BBQCoin', 'Ixcoin', 'BitBar', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Devcoin', 'Terracoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'BBQCoin', 'Ixcoin', 'BitBar', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BBQCoin', 'BitBar', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Devcoin', 'Feathercoin', 'Terracoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Devcoin', 'Feathercoin', 'Terracoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BBQCoin', 'BitBar', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'BitBar', 'BBQCoin', 'Ixcoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'BitBar', 'BBQCoin', 'Ixcoin']
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], ['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], ['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], ['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], ['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], ['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], ['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], ['Bitcoin', '$1,542,813,463.73', '$139.00', '11,099,375', 'BTC'], ['Litecoin', '$74,020,937.66', '$4.30', '17,228,230', 'LTC'], ['Namecoin', '$8,155,721.09', '$1.50', '5,432,800', 'NMC'], ['Peercoin', '$7,052,668.37', '$0.3753', '18,792,078', 'PPC'], ['Terracoin', '$1,582,115.67', '$0.6742', '2,346,830', 'TRC'], ['Devcoin', '$1,491,292.54', '$0.0003406', '4,379,069,952', 'DVC'], ['Novacoin', '$1,183,167.47', '$4.31', '274,227', 'NVC'], ['Bitcoin', '$1,298,954,824.16', '$116. ...
# [[['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], 'https://coinmarketcap.com/historical/20130428/'], [['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], 'https://coinmarketcap.com/historical/20130429/'], [['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], 'https://coinmarketcap.com/historical/20130430/'], [['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], 'https://coinmarketcap.com/historical/20130501/'], [['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], 'https://coinmarketcap.com/historical/20130502/'], [['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], 'https://coinmarketcap.com/historical/20130503/'], [['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], 'https://coinmarketcap.com/historical/20130504/'], [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], 'https://coinmarketcap.com/historical/20130505/'], [['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], 'https://coinmarketcap.com/historical/20130506/'], [['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], 'https://coinmarketcap.com/historical/20130507/'], [['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], 'https://coinmarketcap.com/historical/20130508/'], [['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], 'https://coinmarketcap.com/historical/20130509/'], [['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], 'https://coinmarketcap.com/historical/20130510/'], [['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], 'https://coinmarketcap.com/historical/20130511/'], [['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], 'https://coinmarketcap.com/historical/20130512/'], [['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], 'https://coinmarketcap.com/historical/20130513/'], [['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], 'https://coinmarketcap.com/historical/20130514/'], [['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], 'https://coinmarketcap.com/historical/20130515/'], [['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], 'https://coinmarketcap.com/historical/20130516/'], [['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], 'https://coinmarketcap.com/historical/20130517/'], [['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], 'https://coinmarketcap.com/historical/20130518/'], [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], 'https://coinmarketcap.com/historical/20130519/'], [['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], 'https://coinmarketcap.com/historical/20130520/'], [['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], 'https://coinmarketcap.com/historical/20130521/'], [['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], 'https://coinmarketcap.com/historical/20130522/'], [['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], 'https://coinmarketcap.com/historical/20130523/'], [['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], 'https://coinmarketcap.com/historical/20130524/'], [['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], 'https://coinmarketcap.com/historical/20130525/'], [['Bitcoin', '$1,603,768,790.01', '$144.54', '11,095,675', 'BTC'], 'https://coinmarketcap.com/historical/20130526/'], [['Litecoin', '$75,388,933.89', '$4.38', '17,196,780', 'LTC'], 'https://coinmarketcap.com/historical/20130527/'], [['Peercoin', '$7,673,907.76', '$0.4089', '18,769,008', 'PPC'], 'https://coinmarketcap.com/historical/20130528/'], [['Namecoin', '$7,204,954.88', '$1.33', '5,424,100', 'NMC'], 'https://coinmarketcap.com/historical/20130529/'], [['Terracoin', '$1,657,022.80', '$0.7097', '2,334,850', 'TRC'], 'https://coinmarketcap.com/historical/20130530/'], [['Devcoin', '$1,636,609.70', '$0.0003744', '4,371,769,856', 'DVC'], 'https://coinmarketcap.com/historical/20130531/'], [['Novacoin', '$1,278,294.60', '$4.67', '273,974', 'NVC'], 'https://coinmarketcap.com/his ...

# %% [markdown]
# Try to call the class functions above to the below scraping code

# %%
#create function to scrape data
#example = https://coinmarketcap.com/historical/20220703/'
def crypto_scrape():
    #creating empty lists with which to store data later
    crypto_name_list = []
    crypto_market_cap_list = []
    crypto_price_list = []
    crypto_circulating_supply_list = []
    crypto_ticker_list = []
    
    #creating a data frame for later
    df = pd.DataFrame()
    
    #define url and vary permalink depending on the date
    url = 'https://coinmarketcap.com/historical/20220703'
    
    #request webpage
    webpage = requests.get(url)
    
    #parse the html
    soup = BeautifulSoup(webpage.text, 'html.parser')
   
    #create a variable for the table rows (tr)
    tr = soup.find_all('tr', attrs={'class':'cmc-table-row'})
    
    #creating a counter to iterate through first 10 rows (top 10 cryptocurrencies)
    count = 0
    
    #iterate through the first 10 rows
    for row in tr:
        if count == 10:
            break
        count = count + 1

    #store the name of the coin as a variable by finding td element (column) 
        name_column = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sticky cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--sort-by__name'})
        #find the column within the row and strip the text
        crypto_name = name_column.find('a', attrs={'class': 'cmc-table__column-name--name cmc-link'}).text.strip()
        print(crypto_name)

        #find and createvvariable for market cap
        crypto_market_cap = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__market-cap'}).text.strip()
        print(crypto_market_cap)

        #Find and create variable for the price
        crypto_price = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__price'}).text.strip()
        print(crypto_price)
        #Find and create variable for the circulating supply
        crypto_circulating_supply_and_ticker = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__circulating-supply'}).text.strip()
        print(crypto_circulating_supply_and_ticker)
        #Find and create variable for the circulating supply by splitting the supply+ticker variable
        crypto_ticker = crypto_circulating_supply_and_ticker.split(' ')[1]
        print(crypto_ticker)
        #Find and create variable for the coin ticker
        crypto_circulating_supply = crypto_circulating_supply_and_ticker.split(' ')[0]
        print(crypto_circulating_supply)
        

        #append the data to the associated lists
        crypto_name_list.append(crypto_name)
        crypto_market_cap_list.append(crypto_market_cap)
        crypto_price_list.append(crypto_price)
        crypto_circulating_supply_list.append(crypto_circulating_supply)
        crypto_ticker_list.append(crypto_ticker)

#run the function with a nominated date
crypto_scrape()

# %%
#store the data in a dataframe to make it structured
df['Name'] = crypto_name_list
df['Market cap'] = crypto_market_cap_list
df['Price'] = crypto_price_list
df['Circulating supply'] = crypto_circulating_supply_list
df['Ticker'] = crypto_ticker_list

#show the data
df
# Out:
#           Name           Market cap       Price Circulating supply Ticker
# 0      Bitcoin  $368,272,636,367.55  $19,297.08         19,084,375    BTC
# 1     Ethereum  $130,354,920,626.22   $1,073.77        121,399,635    ETH
# 2       Tether   $66,169,266,578.19     $0.9991     66,230,318,610   USDT
# 3     USD Coin   $55,823,349,220.82       $1.00     55,802,605,113   USDC
# 4          BNB   $35,754,443,110.53     $218.98        163,276,975    BNB
# 5  Binance USD   $17,534,713,957.66     $0.9993     17,547,224,379   BUSD
# 6          XRP   $15,552,125,745.52     $0.3217     48,343,101,197    XRP
# 7      Cardano   $15,377,222,959.95     $0.4556     33,752,565,071    ADA
# 8       Solana   $11,465,283,748.49      $33.39        343,416,618    SOL
# 9     Dogecoin    $8,912,747,929.92    $0.06718    132,670,764,300   DOGE

# %% [markdown]
# instead of generating multiple URLs ahead of time, this code uses selenium to click "next page" to extract the data

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import requests
import time


# function to use Selenium to iteratively click next pages and store data daily and as a compiled list
def click_next_week():
    
    driver.get('https://coinmarketcap.com/historical/20130519/')

    time.sleep(2) # Delay to avoid looking like a bot to server
 

    #parsing html to Beautiful Soup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

   #creating empty lists with which to store one day's worth of data later
    crypto_name_list_one_day = []
    crypto_market_cap_list_one_day = []
    crypto_price_list_one_day = []
    crypto_circulating_supply_list_one_day = []
    crypto_ticker_list_one_day = []

#creating empty lists with which to store all of the daily data
    crypto_name_list = []
    crypto_market_cap_list = []
    crypto_price_list = []
    crypto_circulating_supply_list = []
    crypto_ticker_list = []
    
    



    num_pages = 5

  
    
    
    #page click counter
    page_click_counter = 0
    #creating while loop to click a certain number of pages
    while (page_click_counter < num_pages):
        count = 0
        next_week_button = driver.find_element(by=By.XPATH, value= '//*[@id="__next"]/div[1]/div[2]/div/div[1]/div[2]/div[2]/a[2]')
        
        next_week_button.click()
        
        print('button_clicked')

        

        #create a variable for the table rows (tr)
        tr = soup.find_all('tr', attrs={'class':'cmc-table-row'})
    #iterate through the first 10 rows
        
        while count < 10:
            
               
            
            # increase the counter for appending rows within 1 day
            
            for row in tr:
    #store the name of the coin as a variable by finding td element (column) 
                name_column = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sticky cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--sort-by__name'})
                #find the column within the row and strip the text
                crypto_name = name_column.find('a', attrs={'class': 'cmc-table__column-name--name cmc-link'}).text.strip()
                print(crypto_name)

                #find and createvvariable for market cap
                crypto_market_cap = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__market-cap'}).text.strip()
                print(crypto_market_cap)

                #Find and create variable for the price
                crypto_price = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__price'}).text.strip()
                print(crypto_price)
                #Find and create variable for the circulating supply
                crypto_circulating_supply_and_ticker = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__circulating-supply'}).text.strip()
                print(crypto_circulating_supply_and_ticker)
                #Find and create variable for the circulating supply by splitting the supply+ticker variable
                crypto_ticker = crypto_circulating_supply_and_ticker.split(' ')[1]
                print(crypto_ticker)
                #Find and create variable for the coin ticker
                crypto_circulating_supply = crypto_circulating_supply_and_ticker.split(' ')[0]
                print(crypto_circulating_supply)
                

                #append the data to the associated lists
                crypto_name_list_one_day.append(crypto_name)
                crypto_market_cap_list_one_day.append(crypto_market_cap)
                crypto_price_list_one_day.append(crypto_price)
                crypto_circulating_supply_list_one_day.append(crypto_circulating_supply)
                crypto_ticker_list_one_day.append(crypto_ticker)
                
                count = count +1
            

        crypto_name_list.append(crypto_name_list_one_day)
        
        crypto_market_cap_list.append(crypto_market_cap_list_one_day)
        
        crypto_price_list.append(crypto_price_list_one_day)
     
        crypto_circulating_supply_list.append(crypto_circulating_supply_list_one_day)
      
        crypto_ticker_list.append(crypto_ticker_list_one_day)
        

        next_week_button = driver.find_element(by=By.XPATH, value= '//*[@id="__next"]/div[1]/div[2]/div/div[1]/div[2]/div[2]/a[2]')
        next_week_button.click()
        
    
        page_click_counter += 1 
  
    print(crypto_name_list)
   
    print(crypto_market_cap_list)

    print(crypto_price_list)

    print(crypto_circulating_supply_list)
 
    print(crypto_ticker_list)
click_next_week()
# Out:
# C:\Users\marko\AppData\Local\Temp\ipykernel_13676\4255216893.py:17: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)
# button_clicked
# Bitcoin
# $1,363,205,019.90
# $121.99
# 11,174,725 BTC
# BTC
# 11,174,725
# Litecoin
# $58,760,675.05
# $3.30
# 17,787,454 LTC
# LTC
# 17,787,454
# Namecoin
# $4,789,082.16
# $0.8576
# 5,584,350 NMC
# NMC
# 5,584,350
# Peercoin
# $3,934,412.36
# $0.2074
# 18,971,716 PPC
# PPC
# 18,971,716
# Novacoin
# $1,020,004.70
# $3.62
# 281,908 NVC
# NVC
# 281,908
# Terracoin
# $934,991.48
# $0.3587
# 2,606,970 TRC
# TRC
# 2,606,970
# Devcoin
# $906,212.77
# $0.0002013
# 4,502,170,112 DVC
# DVC
# 4,502,170,112
# Feathercoin
# $833,818.95
# $0.1269
# 6,572,250 FTC
# FTC
# 6,572,250
# Freicoin
# $711,435.19
# $0.03416
# 20,827,516 FRC
# FRC
# 20,827,516
# CHNCoin
# $485,058.81
# $0.09515
# 5,097,714 CNC
# CNC
# 5,097,714
# Mincoin
# $207,096.26
# $0.1952
# 1,061,031 MNC
# MNC
# 1,061,031
# Ixcoin
# $154,515.88
# $0.01221
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $128,439.08
# $42.70
# 3,008 BTB
# BTB
# 3,008
# BBQCoin
# $123,231.29
# $0.007075
# 17,416,812 BQC
# BQC
# 17,416,812
# button_clicked
# Bitcoin
# $1,363,205,019.90
# $121.99
# 11,174,725 BTC
# BTC
# 11,174,725
# Litecoin
# $58,760,675.05
# $3.30
# 17,787,454 LTC
# LTC
# 17,787,454
# Namecoin
# $4,789,082.16
# $0.8576
# 5,584,350 NMC
# NMC
# 5,584,350
# Peercoin
# $3,934,412.36
# $0.2074
# 18,971,716 PPC
# PPC
# 18,971,716
# Novacoin
# $1,020,004.70
# $3.62
# 281,908 NVC
# NVC
# 281,908
# Terracoin
# $934,991.48
# $0.3587
# 2,606,970 TRC
# TRC
# 2,606,970
# Devcoin
# $906,212.77
# $0.0002013
# 4,502,170,112 DVC
# DVC
# 4,502,170,112
# Feathercoin
# $833,818.95
# $0.1269
# 6,572,250 FTC
# FTC
# 6,572,250
# Freicoin
# $711,435.19
# $0.03416
# 20,827,516 FRC
# FRC
# 20,827,516
# CHNCoin
# $485,058.81
# $0.09515
# 5,097,714 CNC
# CNC
# 5,097,714
# Mincoin
# $207,096.26
# $0.1952
# 1,061,031 MNC
# MNC
# 1,061,031
# Ixcoin
# $154,515.88
# $0.01221
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $128,439.08
# $42.70
# 3,008 BTB
# BTB
# 3,008
# BBQCoin
# $123,231.29
# $0.007075
# 17,416,812 BQC
# BQC
# 17,416,812
# button_clicked
# Bitcoin
# $1,363,205,019.90
# $121.99
# 11,174,725 BTC
# BTC
# 11,174,725
# Litecoin
# $58,760,675.05
# $3.30
# 17,787,454 LTC
# LTC
# 17,787,454
# Namecoin
# $4,789,082.16
# $0.8576
# 5,584,350 NMC
# NMC
# 5,584,350
# Peercoin
# $3,934,412.36
# $0.2074
# 18,971,716 PPC
# PPC
# 18,971,716
# Novacoin
# $1,020,004.70
# $3.62
# 281,908 NVC
# NVC
# 281,908
# Terracoin
# $934,991.48
# $0.3587
# 2,606,970 TRC
# TRC
# 2,606,970
# Devcoin
# $906,212.77
# $0.0002013
# 4,502,170,112 DVC
# DVC
# 4,502,170,112
# Feathercoin
# $833,818.95
# $0.1269
# 6,572,250 FTC
# FTC
# 6,572,250
# Freicoin
# $711,435.19
# $0.03416
# 20,827,516 FRC
# FRC
# 20,827,516
# CHNCoin
# $485,058.81
# $0.09515
# 5,097,714 CNC
# CNC
# 5,097,714
# Mincoin
# $207,096.26
# $0.1952
# 1,061,031 MNC
# MNC
# 1,061,031
# Ixcoin
# $154,515.88
# $0.01221
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $128,439.08
# $42.70
# 3,008 BTB
# BTB
# 3,008
# BBQCoin
# $123,231.29
# $0.007075
# 17,416,812 BQC
# BQC
# 17,416,812
# button_clicked
# Bitcoin
# $1,363,205,019.90
# $121.99
# 11,174,725 BTC
# BTC
# 11,174,725
# Litecoin
# $58,760,675.05
# $3.30
# 17,787,454 LTC
# LTC
# 17,787,454
# Namecoin
# $4,789,082.16
# $0.8576
# 5,584,350 NMC
# NMC
# 5,584,350
# Peercoin
# $3,934,412.36
# $0.2074
# 18,971,716 PPC
# PPC
# 18,971,716
# Novacoin
# $1,020,004.70
# $3.62
# 281,908 NVC
# NVC
# 281,908
# Terracoin
# $934,991.48
# $0.3587
# 2,606,970 TRC
# TRC
# 2,606,970
# Devcoin
# $906,212.77
# $0.0002013
# 4,502,170,112 DVC
# DVC
# 4,502,170,112
# Feathercoin
# $833,818.95
# $0.1269
# 6,572,250 FTC
# FTC
# 6,572,250
# Freicoin
# $711,435.19
# $0.03416
# 20,827,516 FRC
# FRC
# 20,827,516
# CHNCoin
# $485,058.81
# $0.09515
# 5,097,714 CNC
# CNC
# 5,097,714
# Mincoin
# $207,096.26
# $0.1952
# 1,061,031 MNC
# MNC
# 1,061,031
# Ixcoin
# $154,515.88
# $0.01221
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $128,439.08
# $42.70
# 3,008 BTB
# BTB
# 3,008
# BBQCoin
# $123,231.29
# $0.007075
# 17,416,812 BQC
# BQC
# 17,416,812
# button_clicked
# Bitcoin
# $1,363,205,019.90
# $121.99
# 11,174,725 BTC
# BTC
# 11,174,725
# Litecoin
# $58,760,675.05
# $3.30
# 17,787,454 LTC
# LTC
# 17,787,454
# Namecoin
# $4,789,082.16
# $0.8576
# 5,584,350 NMC
# NMC
# 5,584,350
# Peercoin
# $3,934,412.36
# $0.2074
# 18,971,716 PPC
# PPC
# 18,971,716
# Novacoin
# $1,020,004.70
# $3.62
# 281,908 NVC
# NVC
# 281,908
# Terracoin
# $934,991.48
# $0.3587
# 2,606,970 TRC
# TRC
# 2,606,970
# Devcoin
# $906,212.77
# $0.0002013
# 4,502,170,112 DVC
# DVC
# 4,502,170,112
# Feathercoin
# $833,818.95
# $0.1269
# 6,572,250 FTC
# FTC
# 6,572,250
# Freicoin
# $711,435.19
# $0.03416
# 20,827,516 FRC
# FRC
# 20,827,516
# CHNCoin
# $485,058.81
# $0.09515
# 5,097,714 CNC
# CNC
# 5,097,714
# Mincoin
# $207,096.26
# $0.1952
# 1,061,031 MNC
# MNC
# 1,061,031
# Ixcoin
# $154,515.88
# $0.01221
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $128,439.08
# $42.70
# 3,008 BTB
# BTB
# 3,008
# BBQCoin
# $123,231.29
# $0.007075
# 17,416,812 BQC
# BQC
# 17,416,812
# [['Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin'], ['Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin'], ['Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin'], ['Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin'], ['Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devco ...
# [['$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29'], ['$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29'], ['$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29'], ['$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$ ...
# [['$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075'], ['$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075'], ['$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075'], ['$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075'], ['$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075']]
# [['11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812'], ['11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812'], ['11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812'], ['11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812'], ['11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,50 ...
# [['BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC'], ['BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC'], ['BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC'], ['BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC'], ['BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC']]
