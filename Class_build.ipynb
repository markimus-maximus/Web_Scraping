# %%
import requests
import ast
from bs4 import  BeautifulSoup
from datetime import date, datetime
import pandas as pd
import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By
import os
import json
import urllib.request
from pathlib import Path
import uuid

# %%
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)
global list_dates
list_dates = []
url_list = []
start_date = date(2013, 4, 28)
end_date = date(2022, 7, 3)
for single_date in daterange(start_date, end_date):

    list = str(single_date.strftime("%Y%m%d/"))
   
    list_dates.append(list)

print(list_dates)
# Out:
# ['20130428/', '20130429/', '20130430/', '20130501/', '20130502/', '20130503/', '20130504/', '20130505/', '20130506/', '20130507/', '20130508/', '20130509/', '20130510/', '20130511/', '20130512/', '20130513/', '20130514/', '20130515/', '20130516/', '20130517/', '20130518/', '20130519/', '20130520/', '20130521/', '20130522/', '20130523/', '20130524/', '20130525/', '20130526/', '20130527/', '20130528/', '20130529/', '20130530/', '20130531/', '20130601/', '20130602/', '20130603/', '20130604/', '20130605/', '20130606/', '20130607/', '20130608/', '20130609/', '20130610/', '20130611/', '20130612/', '20130613/', '20130614/', '20130615/', '20130616/', '20130617/', '20130618/', '20130619/', '20130620/', '20130621/', '20130622/', '20130623/', '20130624/', '20130625/', '20130626/', '20130627/', '20130628/', '20130629/', '20130630/', '20130701/', '20130702/', '20130703/', '20130704/', '20130705/', '20130706/', '20130707/', '20130708/', '20130709/', '20130710/', '20130711/', '20130712/', '20130713/', '20130714/', '20130715/', '20130716/', '20130717/', '20130718/', '20130719/', '20130720/', '20130721/', '20130722/', '20130723/', '20130724/', '20130725/', '20130726/', '20130727/', '20130728/', '20130729/', '20130730/', '20130731/', '20130801/', '20130802/', '20130803/', '20130804/', '20130805/', '20130806/', '20130807/', '20130808/', '20130809/', '20130810/', '20130811/', '20130812/', '20130813/', '20130814/', '20130815/', '20130816/', '20130817/', '20130818/', '20130819/', '20130820/', '20130821/', '20130822/', '20130823/', '20130824/', '20130825/', '20130826/', '20130827/', '20130828/', '20130829/', '20130830/', '20130831/', '20130901/', '20130902/', '20130903/', '20130904/', '20130905/', '20130906/', '20130907/', '20130908/', '20130909/', '20130910/', '20130911/', '20130912/', '20130913/', '20130914/', '20130915/', '20130916/', '20130917/', '20130918/', '20130919/', '20130920/', '20130921/', '20130922/', '20130923/', '20130924/', '20130925/', '20130926/', '20130927/', '20130928/', '20130929/', '20130930/', '20131001/', '20131002/', '20131003/', '20131004/', '20131005/', '20131006/', '20131007/', '20131008/', '20131009/', '20131010/', '20131011/', '20131012/', '20131013/', '20131014/', '20131015/', '20131016/', '20131017/', '20131018/', '20131019/', '20131020/', '20131021/', '20131022/', '20131023/', '20131024/', '20131025/', '20131026/', '20131027/', '20131028/', '20131029/', '20131030/', '20131031/', '20131101/', '20131102/', '20131103/', '20131104/', '20131105/', '20131106/', '20131107/', '20131108/', '20131109/', '20131110/', '20131111/', '20131112/', '20131113/', '20131114/', '20131115/', '20131116/', '20131117/', '20131118/', '20131119/', '20131120/', '20131121/', '20131122/', '20131123/', '20131124/', '20131125/', '20131126/', '20131127/', '20131128/', '20131129/', '20131130/', '20131201/', '20131202/', '20131203/', '20131204/', '20131205/', '20131206/', '20131207/', '20131208/', '20131209/', '20131210/', '20131211/', '20131212/', '20131213/', '20131214/', '20131215/', '20131216/', '20131217/', '20131218/', '20131219/', '20131220/', '20131221/', '20131222/', '20131223/', '20131224/', '20131225/', '20131226/', '20131227/', '20131228/', '20131229/', '20131230/', '20131231/', '20140101/', '20140102/', '20140103/', '20140104/', '20140105/', '20140106/', '20140107/', '20140108/', '20140109/', '20140110/', '20140111/', '20140112/', '20140113/', '20140114/', '20140115/', '20140116/', '20140117/', '20140118/', '20140119/', '20140120/', '20140121/', '20140122/', '20140123/', '20140124/', '20140125/', '20140126/', '20140127/', '20140128/', '20140129/', '20140130/', '20140131/', '20140201/', '20140202/', '20140203/', '20140204/', '20140205/', '20140206/', '20140207/', '20140208/', '20140209/', '20140210/', '20140211/', '20140212/', '20140213/', '20140214/', '20140215/', '20140216/', '20140217/', '20140218/', '20140219/', '20140220/', '20140221/', '20140222/', '20140223/', '20140224/', '20140225/', '20140226/', '20140227/', '20140228/', '2014030 ...

# %%
from time import strptime


class Scraper: 
    

    def __init__(self):
        import requests
        import ast
        from bs4 import  BeautifulSoup
        import time
        import pandas as pd
        from datetime import timedelta, date
        from selenium import webdriver
        from selenium.webdriver.common.by import By
        import os
        import json
        import urllib.request
        from pathlib import Path

        date_list = []
    #function for initialising webdriver and requesting url. This saves repeating code in the subsequent methods, and 
    # streamlines declaring url variable to one method.  Alsways call this method first, obviously
    
    def webdriver_init(self, url):

        driver = webdriver.Chrome('C:\\Users\\marko\\chromedriver.exe')
        request = driver.get(url)
        time.sleep(2) # Delay to avoid looking like a bot to server
    
    
    

    '''function for concatenating list of permalinks to given url, returning a list of unique urls containing url and permalink.
     the list attribute is the pre-made list of url permalinks (e.g. date_list from daterange function). Furthermore, this function creates a uuid for each unique iteration in the list'''
     

    def create_url_list_with_date_permalinks(self, list, url):

        global url_list 
        url_list = []
        
        
        for url_extension in list:
            url_instance = url + str(url_extension)
            url_list.append(url_instance)
        
        url_list = url_list[::7]
        print(url_list)

    # This method generates UUIDs for every record in the method attribute list. This UUID is then
    # stored in a list. This function then takes other lists of interest to generate a dictionary
    # including the UUID and the record of interest. Record_list_1 can be the defining
    #feautre such as the webpage url or date of the record.  The dictionary
    # is then converted to a JSON file and saved in a folder
    
    def UUID_dictionary(self, record_list):

        global uuid_list
        uuid_list = []
        #generate a pseudo-unique uuid for every record in the list by taking the length of the list
        for UUID in range(len(record_list)):
            #generates 1 uuid4 and converts to string (this is easier for dictionary saving to JSON)
            single_uuid = str(uuid.uuid4())
            #append the UUID to the list
            uuid_list.append(single_uuid)
        #making the dictionary with the record list and the uuid list just generated
        global record_uuid_dict
        record_uuid_dict = dict(zip(uuid_list, record_list))
        
        x = record_uuid_dict.keys()
        print(x)
        print(record_uuid_dict)
        
        #make a folder if the folder doesn't exist
        if not os.path.exists('raw_data'):
            os.makedirs('raw_data')
       
       #make json data file if it doesn't already exist
        
        json.dump(record_uuid_dict, fp)
        # moving the json file to a different directory- is there a more efficient way of doing this?
        Path(r"C:\Users\marko\Desktop\Web_Scraping\data.json").rename(r"C:\Users\marko\Desktop\Web_Scraping\raw_data\data.json")

        
    

        
    #This method gets all image src from allocated webpage and appends to a list

    def get_image_list_from_webpage(self):
    #define url and vary permalink depending on the date
        url = 'https://coinmarketcap.com/historical/20220703'
        
        #request webpage
        webpage = requests.get(url)
        
        #parse the html
        soup = BeautifulSoup(webpage.text, 'html.parser')

        #create a variable for the table rows (tr)
        images = soup.find_all('img')
        #create image list
        image_list = []
        # iterate through every src and extract only the src text
        for image in images:
            #strips the src url only
            image = image['src']
            #appends stripped url to list
            image_list.append(image)
        print(image_list)

    #method to click through set number of pages (num_pages) by clicking on an allocated 'next page' button XPath 
    #useful funtion to integrate into code for webscraping
        def page_click_and_count(self, num_pages, next_week_button_XPath):
            
            page_click_counter = 0
            #creating while loop to click a certain number of pages
            while (page_click_counter < num_pages):
                count = 0
                next_week_button = driver.find_element(by=By.XPATH, value= 'next_week_button_XPath')
                
                next_week_button.click()
                
                print('button_clicked')

                page_click_counter += 1 
   

    

#saves an image in a particular file, NEED TO WORK OUT WHY CAN'T SET DIRECTORY TO THE BELOW NOMINATED FOLDER AS OPPOSED TO DEFAU;LT PATH
    def save_images_from_webpage(self):
      

        urllib.request.urlretrieve('https://s2.coinmarketcap.com/static/img/coins/32x32/1.png', r"C:\Users\marko\Desktop\Web_Scraping\Web pictures.jpg")
        

            
       
           

     
    
        

    #method for bypassing cookies, example: amazon.co.uk

    def cookies_bypass(self, XPath):

        time.sleep(2) # Delay to avoid looking like a bot to server

        try: 
            accept_cookies_button = driver.find_element(by=By.XPATH, value= XPath)
            accept_cookies_button.click()

        except: pass

    #method for logging into webpage

    def auto_login(self, email_address, password):
    
        
        # input the username string
        XPath_email_field = input('What is the XPath for inputting email_address?')
        username = driver.find_element(by=By.XPATH, value= XPath_email_field)
        username.send_keys(email_address)

        # click continue to send username 
        XPath_click_conitnue_login = input('What is the XPath for pressing continue?')
        username_send_click = driver.find_element(by=By.XPATH, value= XPath_click_conitnue_login)
        username_send_click.click()

        #input the password string
        XPath_input_password = input('What is the XPath for inputting password?')
        password = driver.find_element(by=By.XPATH, value= XPath_input_password)
        password.send_keys("password")

        #click continue to send password
        XPath_click_login = input('What is the XPath for clicking login?')
        password_send_click = driver.find_element(by=By.XPATH, value= XPath_click_login)
        password_send_click.click()

    #This method scrolls a webpage using selenium. Input the url, and the x,y coordinaytes for the 
    #location to scroll to. Simply scrolling down would leave x as 0. A full HD monitor is 1080 in the y
    #plane, so to scroll to the bottom would be (0,1080)

    def scroll_page(self, x, y):

        driver.execute_script("window.scrollTo({},{}).".format(x,y))

        time.sleep(2) # Delay to avoid looking like a bot to server

        scroll_page(url)

    #code for clicking off notification alert (:2 is diable notifications)
    
    def click_notifications():
        chrome_options = webdriver.ChromeOptions()
        prefs = {"profile.default_content_setting_values.notifications" : 2}
        chrome_options.add_experimental_option("prefs",prefs)
        driver = webdriver.Chrome(chrome_options=chrome_options)

## link the daily scraped data below to theurl and dictionary

     #creating empty lists with which to store many days of data. Item_limit = number of cyptocurrencies
     #to scrape. num_pages is the number of webpages to go though
    def crypto_scrape_multi_days(self, daily_item_limit, num_pages):

#creating empty lists with which to store  all of the weekly data
            global crypto_name_list
            crypto_name_list = []
            global crypto_market_cap_list
            crypto_market_cap_list = []
            global crypto_price_list
            crypto_price_list = []
            global crypto_circulating_supply_list
            crypto_circulating_supply_list = []
            global crypto_ticker_list
            crypto_ticker_list = []

              #creating lists to store the weekly data (one day a week)
            crypto_name_list_one_day = []
            crypto_market_cap_list_one_day = []
            crypto_price_list_one_day = []
            crypto_circulating_supply_list_one_day = []
            crypto_ticker_list_one_day = []

            #creating lists for each daily entry
            global daily_records_combined_list
            daily_records_combined_list = []


            for url in url_list[:num_pages]:

             
            #creating a data frame for later
                df = pd.DataFrame()
            
                #request webpage
                webpage = requests.get(url)
            
                #parse the html
                soup = BeautifulSoup(webpage.text, 'html.parser')
        
      

        
            
                count = 0

            

                #create a variable for the table rows (tr), limited to the first 10, this can be changed to anything with attribute
                tr = soup.find_all('tr', attrs={'class':'cmc-table-row'})
                #The number of records per page, useful for scraping all records 
                tr_length = len(tr)
                print(tr_length)
              
                    
                for row in tr:
            #store the name of the coin as a variable by finding td element (column) 
                    name_column = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sticky cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--sort-by__name'})
                    if name_column == None:
                        break
                    #find the column within the row and strip the text
                    crypto_name = name_column.find('a', attrs={'class': 'cmc-table__column-name--name cmc-link'}).text.strip()
                    print(crypto_name)

                    #find and createvvariable for market cap
                    crypto_market_cap = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__market-cap'}).text.strip()
                    print(crypto_market_cap)

                    #Find and create variable for the price
                    crypto_price = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__price'}).text.strip()
                    print(crypto_price)
                    #Find and create variable for the circulating supply
                    crypto_circulating_supply_and_ticker = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__circulating-supply'}).text.strip()
                    print(crypto_circulating_supply_and_ticker)
                    #Find and create variable for the circulating supply by splitting the supply+ticker variable
                    crypto_ticker = crypto_circulating_supply_and_ticker.split(' ')[1]
                    print(crypto_ticker)
                    #Find and create variable for the coin ticker
                    crypto_circulating_supply = crypto_circulating_supply_and_ticker.split(' ')[0]
                    print(crypto_circulating_supply)
                    

                    #append the data to the associated lists
                    crypto_name_list.append(crypto_name)
                   
                    crypto_market_cap_list.append(crypto_market_cap)
                    crypto_price_list.append(crypto_price)
                    crypto_circulating_supply_list.append(crypto_circulating_supply)
                    crypto_ticker_list.append(crypto_ticker)
                    # increase the counter for appending rows within 1 day   

                    count += 1
                    if count == tr_length:
                        break
                    
                
            print(len(crypto_name_list))
            print(len(crypto_circulating_supply_list))
            print(len(crypto_market_cap_list))
            print(len(crypto_price_list))
            print(len(crypto_ticker_list))
            print(crypto_name_list)   
        

        #this code packages each record into a list: for example BTC price from a particular date. These lists can then be added to a 
        # dictionary. This function could be broadly applicable to any collection of lists which yield corresponding data from the same index
            
            for i in range(len(crypto_name_list)):
                daily_records_combined_list.append([crypto_name_list[i],crypto_market_cap_list[i],crypto_price_list[i],crypto_circulating_supply_list[i],crypto_ticker_list[i]])  
            print(daily_records_combined_list)

   
    #shortest_list_list is the list with the shortest number of indices (prevents out of range error), Lists 1 and 2 are the lists to be appended
    #  together
    def list_zipper(self, shortest_list, List_1, List_2): 
            #define list for appending the lists into
            global combined_lists
            combined_lists = []
            #this code packages records from lists into another list based on the index of the record. These lists can then be added to a 
        # 
            for i in range(len(shortest_list)):
                combined_lists.append([List_1[i], List_2[i]])
            
            print(combined_lists)



    
    
            
               

            
                
            
                
    





if __name__ =="__main__":
    Scraper()

# %%
yolo = Scraper()
yolo.crypto_scrape_multi_days(10, 20)
#yolo.UUID_dictionary(url_list)
yolo.list_zipper(daily_records_combined_list, daily_records_combined_list, url_list)
        




    

    

    
     



## link the daily scraped data below to the url and dictionary
# Out:
# 7
# Bitcoin
# $1,488,566,971.96
# $134.21
# 11,091,325 BTC
# BTC
# 11,091,325
# Litecoin
# $74,637,021.57
# $4.35
# 17,164,230 LTC
# LTC
# 17,164,230
# Peercoin
# $7,250,186.65
# $0.3865
# 18,757,362 PPC
# PPC
# 18,757,362
# Namecoin
# $5,995,997.19
# $1.11
# 5,415,300 NMC
# NMC
# 5,415,300
# Terracoin
# $1,503,099.40
# $0.6469
# 2,323,570 TRC
# TRC
# 2,323,570
# Devcoin
# $1,424,087.30
# $0.0003261
# 4,366,620,160 DVC
# DVC
# 4,366,620,160
# Novacoin
# $1,162,266.30
# $4.25
# 273,706 NVC
# NVC
# 273,706
# 10
# Bitcoin
# $1,288,693,216.22
# $115.91
# 11,118,050 BTC
# BTC
# 11,118,050
# Litecoin
# $62,298,217.32
# $3.59
# 17,348,954 LTC
# LTC
# 17,348,954
# Namecoin
# $6,290,543.05
# $1.15
# 5,465,350 NMC
# NMC
# 5,465,350
# Peercoin
# $5,718,446.46
# $0.3037
# 18,830,240 PPC
# PPC
# 18,830,240
# Feathercoin
# $2,017,436.23
# $0.313
# 6,444,650 FTC
# FTC
# 6,444,650
# Freicoin
# $1,627,438.51
# $0.08114
# 20,057,908 FRC
# FRC
# 20,057,908
# Terracoin
# $1,367,162.39
# $0.568
# 2,407,150 TRC
# TRC
# 2,407,150
# Devcoin
# $1,052,081.53
# $0.0002388
# 4,406,170,112 DVC
# DVC
# 4,406,170,112
# Novacoin
# $1,015,804.46
# $3.69
# 275,503 NVC
# NVC
# 275,503
# Mincoin
# $118,657.23
# $0.1159
# 1,023,701 MNC
# MNC
# 1,023,701
# 14
# Bitcoin
# $1,281,982,625.00
# $115.00
# 11,147,675 BTC
# BTC
# 11,147,675
# Litecoin
# $57,513,319.09
# $3.27
# 17,591,130 LTC
# LTC
# 17,591,130
# Namecoin
# $4,674,413.40
# $0.8464
# 5,522,700 NMC
# NMC
# 5,522,700
# Peercoin
# $4,585,556.07
# $0.2427
# 18,897,820 PPC
# PPC
# 18,897,820
# Novacoin
# $984,531.38
# $3.52
# 279,685 NVC
# NVC
# 279,685
# Devcoin
# $983,447.61
# $0.0002208
# 4,454,020,096 DVC
# DVC
# 4,454,020,096
# Terracoin
# $954,262.84
# $0.3807
# 2,506,930 TRC
# TRC
# 2,506,930
# Feathercoin
# $820,221.45
# $0.1253
# 6,543,450 FTC
# FTC
# 6,543,450
# Freicoin
# $748,241.76
# $0.03596
# 20,807,988 FRC
# FRC
# 20,807,988
# CHNCoin
# $489,370.40
# $0.0966
# 5,065,946 CNC
# CNC
# 5,065,946
# Mincoin
# $247,203.65
# $0.237
# 1,042,987 MNC
# MNC
# 1,042,987
# BBQCoin
# $156,410.47
# $0.0092
# 17,001,138 BQC
# BQC
# 17,001,138
# Ixcoin
# $147,029.97
# $0.01162
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $82,905.80
# $28.86
# 2,872 BTB
# BTB
# 2,872
# 14
# Bitcoin
# $1,363,205,019.90
# $121.99
# 11,174,725 BTC
# BTC
# 11,174,725
# Litecoin
# $58,760,675.05
# $3.30
# 17,787,454 LTC
# LTC
# 17,787,454
# Namecoin
# $4,789,082.16
# $0.8576
# 5,584,350 NMC
# NMC
# 5,584,350
# Peercoin
# $3,934,412.36
# $0.2074
# 18,971,716 PPC
# PPC
# 18,971,716
# Novacoin
# $1,020,004.70
# $3.62
# 281,908 NVC
# NVC
# 281,908
# Terracoin
# $934,991.48
# $0.3587
# 2,606,970 TRC
# TRC
# 2,606,970
# Devcoin
# $906,212.77
# $0.0002013
# 4,502,170,112 DVC
# DVC
# 4,502,170,112
# Feathercoin
# $833,818.95
# $0.1269
# 6,572,250 FTC
# FTC
# 6,572,250
# Freicoin
# $711,435.19
# $0.03416
# 20,827,516 FRC
# FRC
# 20,827,516
# CHNCoin
# $485,058.81
# $0.09515
# 5,097,714 CNC
# CNC
# 5,097,714
# Mincoin
# $207,096.26
# $0.1952
# 1,061,031 MNC
# MNC
# 1,061,031
# Ixcoin
# $154,515.88
# $0.01221
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $128,439.08
# $42.70
# 3,008 BTB
# BTB
# 3,008
# BBQCoin
# $123,231.29
# $0.007075
# 17,416,812 BQC
# BQC
# 17,416,812
# 15
# Bitcoin
# $1,495,292,967.14
# $133.48
# 11,202,375 BTC
# BTC
# 11,202,375
# Litecoin
# $58,458,016.95
# $3.25
# 17,993,154 LTC
# LTC
# 17,993,154
# Namecoin
# $5,251,485.27
# $0.9304
# 5,644,600 NMC
# NMC
# 5,644,600
# Peercoin
# $3,612,498.62
# $0.1895
# 19,059,134 PPC
# PPC
# 19,059,134
# Novacoin
# $1,225,595.40
# $4.31
# 284,444 NVC
# NVC
# 284,444
# Devcoin
# $915,607.00
# $0.0002016
# 4,542,720,000 DVC
# DVC
# 4,542,720,000
# Terracoin
# $842,448.90
# $0.3123
# 2,697,190 TRC
# TRC
# 2,697,190
# Freicoin
# $687,220.00
# $0.0327
# 21,014,232 FRC
# FRC
# 21,014,232
# Feathercoin
# $654,331.38
# $0.09878
# 6,624,450 FTC
# FTC
# 6,624,450
# CHNCoin
# $374,915.45
# $0.07341
# 5,106,866 CNC
# CNC
# 5,106,866
# Mincoin
# $130,393.11
# $0.1218
# 1,070,899 MNC
# MNC
# 1,070,899
# Ixcoin
# $127,367.86
# $0.01007
# 12,653,618 IXC *
# IXC
# 12,653,618
# BBQCoin
# $114,258.29
# $0.006407
# 17,833,240 BQC
# BQC
# 17,833,240
# WorldCoin
# $61,369.21
# $0.02565
# 2,392,562 WDC
# WDC
# 2,392,562
# BitBar
# $54,030.08
# $17.36
# 3,113 BTB
# BTB
# 3,113
# 14
# Bitcoin
# $1,373,839,383.45
# $122.29
# 11,234,075 BTC
# BTC
# 11,234,075
# Litecoin
# $49,625,738.78
# $2.73
# 18,197,154 LTC
# LTC
# 18,197,154
# Namecoin
# $4,038,794.14
# $0.7093
# 5,694,100 NMC
# NMC
# 5,694,100
# Peercoin
# $2,899,779.44
# $0.1516
# 19,122,498 PPC
# PPC
# 19,122,498
# Novacoin
# $1,117,980.01
# $3.90
# 286,310 NVC
# NVC
# 286,310
# Devcoin
# $674,189.93
# $0.0001468
# 4,594,120,192 DVC
# DVC
# 4,594,120,192
# Terracoin
# $662,838.49
# $0.2385
# 2,779,550 TRC
# TRC
# 2,779,550
# Feathercoin
# $545,794.55
# $0.08194
# 6,661,250 FTC
# FTC
# 6,661,250
# Freicoin
# $417,750.51
# $0.01981
# 21,086,442 FRC
# FRC
# 21,086,442
# CHNCoin
# $287,451.99
# $0.05625
# 5,109,858 CNC
# CNC
# 5,109,858
# Ixcoin
# $86,656.55
# $0.006848
# 12,653,618 IXC *
# IXC
# 12,653,618
# Mincoin
# $78,887.29
# $0.07338
# 1,075,103 MNC
# MNC
# 1,075,103
# BBQCoin
# $76,751.02
# $0.004207
# 18,244,294 BQC
# BQC
# 18,244,294
# BitBar
# $52,295.84
# $15.91
# 3,287 BTB
# BTB
# 3,287
# 20
# Bitcoin
# $1,126,642,500.00
# $100.00
# 11,266,425 BTC
# BTC
# 11,266,425
# Litecoin
# $43,858,288.59
# $2.38
# 18,404,654 LTC
# LTC
# 18,404,654
# Namecoin
# $3,311,798.26
# $0.576
# 5,749,650 NMC
# NMC
# 5,749,650
# Peercoin
# $2,267,778.06
# $0.118
# 19,218,458 PPC
# PPC
# 19,218,458
# Novacoin
# $953,097.98
# $3.31
# 288,381 NVC
# NVC
# 288,381
# Feathercoin
# $852,774.31
# $0.126
# 6,768,050 FTC
# FTC
# 6,768,050
# Terracoin
# $556,761.98
# $0.195
# 2,855,190 TRC
# TRC
# 2,855,190
# Devcoin
# $538,224.93
# $0.000116
# 4,639,869,952 DVC
# DVC
# 4,639,869,952
# Freicoin
# $344,283.64
# $0.01613
# 21,345,628 FRC
# FRC
# 21,345,628
# CHNCoin
# $260,701.49
# $0.051
# 5,111,794 CNC
# CNC
# 5,111,794
# BBQCoin
# $98,890.42
# $0.0053
# 18,658,570 BQC
# BQC
# 18,658,570
# Yacoin
# $98,315.19
# $0.0302
# 3,255,470 YAC
# YAC
# 3,255,470
# Digitalcoin
# $70,346.91
# $0.0392
# 1,794,564 DGC
# DGC
# 1,794,564
# WorldCoin
# $60,438.16
# $0.01287
# 4,696,050 WDC
# WDC
# 4,696,050
# BitBar
# $45,586.21
# $13.10
# 3,479 BTB
# BTB
# 3,479
# Mincoin
# $44,972.33
# $0.0411
# 1,094,217 MNC
# MNC
# 1,094,217
# Memecoin
# $14,865.88
# $0.001715
# 8,668,150 MEM
# MEM
# 8,668,150
# AmericanCoin
# $4,150.01
# $0.004178
# 993,300 AMC
# AMC
# 993,300
# Franko
# $2,772.80
# $0.15
# 18,485 FRK
# FRK
# 18,485
# Elacoin
# $768.13
# $0.036
# 21,337 ELC
# ELC
# 21,337
# 24
# Bitcoin
# $1,124,306,468.29
# $99.51
# 11,298,425 BTC
# BTC
# 11,298,425
# Litecoin
# $39,617,176.03
# $2.13
# 18,603,854 LTC
# LTC
# 18,603,854
# Namecoin
# $2,313,381.58
# $0.3951
# 5,855,850 NMC
# NMC
# 5,855,850
# Peercoin
# $2,131,363.14
# $0.1105
# 19,296,016 PPC
# PPC
# 19,296,016
# Novacoin
# $943,738.73
# $3.25
# 290,648 NVC
# NVC
# 290,648
# Feathercoin
# $817,909.00
# $0.1085
# 7,540,700 FTC
# FTC
# 7,540,700
# Terracoin
# $468,510.18
# $0.1602
# 2,924,330 TRC
# TRC
# 2,924,330
# Devcoin
# $411,176.50
# $0.00008774
# 4,686,519,808 DVC
# DVC
# 4,686,519,808
# Freicoin
# $386,099.25
# $0.01791
# 21,554,378 FRC
# FRC
# 21,554,378
# CHNCoin
# $216,136.99
# $0.04179
# 5,171,458 CNC
# CNC
# 5,171,458
# BBQCoin
# $83,118.07
# $0.004359
# 19,070,168 BQC
# BQC
# 19,070,168
# Digitalcoin
# $71,553.91
# $0.02987
# 2,395,198 DGC
# DGC
# 2,395,198
# Yacoin
# $70,774.48
# $0.0199
# 3,556,148 YAC
# YAC
# 3,556,148
# WorldCoin
# $56,980.47
# $0.009473
# 6,014,815 WDC
# WDC
# 6,014,815
# Mincoin
# $37,617.32
# $0.03393
# 1,108,579 MNC
# MNC
# 1,108,579
# BitBar
# $21,486.74
# $5.97
# 3,599 BTB
# BTB
# 3,599
# GoldCoin
# $19,834.44
# $0.001462
# 13,566,450 GLC
# GLC
# 13,566,450
# Memecoin
# $8,474.66
# $0.0008163
# 10,381,550 MEM
# MEM
# 10,381,550
# Luckycoin
# $7,949.17
# $0.002512
# 3,164,008 LKY
# LKY
# 3,164,008
# Franko
# $4,284.35
# $0.1939
# 22,091 FRK
# FRK
# 22,091
# 26
# Bitcoin
# $1,218,626,731.94
# $107.60
# 11,325,525 BTC
# BTC
# 11,325,525
# Litecoin
# $58,663,951.67
# $3.12
# 18,819,604 LTC
# LTC
# 18,819,604
# Namecoin
# $3,329,217.96
# $0.5627
# 5,916,000 NMC
# NMC
# 5,916,000
# Peercoin
# $2,358,403.70
# $0.1216
# 19,396,678 PPC
# PPC
# 19,396,678
# Novacoin
# $1,042,586.72
# $3.50
# 298,137 NVC
# NVC
# 298,137
# Feathercoin
# $799,217.02
# $0.09899
# 8,073,550 FTC
# FTC
# 8,073,550
# Terracoin
# $416,782.31
# $0.1399
# 2,979,570 TRC
# TRC
# 2,979,570
# Devcoin
# $407,340.96
# $0.00008608
# 4,732,120,064 DVC
# DVC
# 4,732,120,064
# Freicoin
# $274,484.38
# $0.01259
# 21,801,296 FRC
# FRC
# 21,801,296
# CHNCoin
# $135,261.23
# $0.02582
# 5,237,810 CNC
# CNC
# 5,237,810
# Digitalcoin
# $84,169.38
# $0.02819
# 2,985,547 DGC
# DGC
# 2,985,547
# Yacoin
# $82,023.91
# $0.02163
# 3,792,557 YAC
# YAC
# 3,792,557
# BBQCoin
# $79,853.09
# $0.0041
# 19,478,450 BQC
# BQC
# 19,478,450
# Ixcoin
# $68,433.51
# $0.00495
# 13,826,066 IXC *
# IXC
# 13,826,066
# WorldCoin
# $67,830.58
# $0.009766
# 6,945,743 WDC
# WDC
# 6,945,743
# BitBar
# $24,643.61
# $6.56
# 3,755 BTB
# BTB
# 3,755
# Mincoin
# $24,316.38
# $0.02153
# 1,129,661 MNC
# MNC
# 1,129,661
# GoldCoin
# $18,141.18
# $0.001188
# 15,263,950 GLC
# GLC
# 15,263,950
# Memecoin
# $13,338.13
# $0.00109
# 12,236,950 MEM
# MEM
# 12,236,950
# Bytecoin
# $11,370.84
# $0.01238
# 918,850 BTE
# BTE
# 918,850
# 26
# Bitcoin
# $1,096,957,926.58
# $96.61
# 11,354,025 BTC
# BTC
# 11,354,025
# Litecoin
# $56,721,517.99
# $2.98
# 19,030,604 LTC
# LTC
# 19,030,604
# Namecoin
# $2,995,222.23
# $0.5014
# 5,973,400 NMC
# NMC
# 5,973,400
# Peercoin
# $2,367,684.20
# $0.1217
# 19,449,710 PPC
# PPC
# 19,449,710
# Novacoin
# $931,437.38
# $3.09
# 301,181 NVC
# NVC
# 301,181
# Feathercoin
# $694,353.94
# $0.07826
# 8,872,700 FTC
# FTC
# 8,872,700
# Terracoin
# $395,910.40
# $0.1304
# 3,035,450 TRC
# TRC
# 3,035,450
# Devcoin
# $350,826.66
# $0.00007343
# 4,777,920,000 DVC
# DVC
# 4,777,920,000
# Freicoin
# $274,804.66
# $0.01256
# 21,879,664 FRC
# FRC
# 21,879,664
# Digitalcoin
# $93,810.47
# $0.02619
# 3,582,563 DGC
# DGC
# 3,582,563
# Yacoin
# $92,500.45
# $0.02338
# 3,956,292 YAC
# YAC
# 3,956,292
# BBQCoin
# $76,284.42
# $0.003836
# 19,888,648 BQC
# BQC
# 19,888,648
# WorldCoin
# $55,160.81
# $0.007942
# 6,945,743 WDC
# WDC
# 6,945,743
# Ixcoin
# $51,205.23
# $0.003671
# 13,947,314 IXC *
# IXC
# 13,947,314
# CHNCoin
# $45,596.16
# $0.008695
# 5,243,794 CNC
# CNC
# 5,243,794
# Mincoin
# $42,677.67
# $0.0372
# 1,147,361 MNC
# MNC
# 1,147,361
# BitBar
# $23,567.27
# $5.91
# 3,986 BTB
# BTB
# 3,986
# Luckycoin
# $12,095.08
# $0.002618
# 4,619,548 LKY
# LKY
# 4,619,548
# Memecoin
# $10,668.84
# $0.0007604
# 14,031,450 MEM
# MEM
# 14,031,450
# GoldCoin
# $6,496.10
# $0.0003879
# 16,745,950 GLC
# GLC
# 16,745,950
# 40
# Bitcoin
# $848,838,935.56
# $74.56
# 11,384,475 BTC
# BTC
# 11,384,475
# Litecoin
# $51,099,940.90
# $2.66
# 19,235,004 LTC
# LTC
# 19,235,004
# Namecoin
# $2,598,102.11
# $0.4369
# 5,946,293 NMC
# NMC
# 5,946,293
# Peercoin
# $2,582,887.38
# $0.132
# 19,571,310 PPC
# PPC
# 19,571,310
# Novacoin
# $867,500.25
# $2.84
# 305,695 NVC
# NVC
# 305,695
# Feathercoin
# $711,870.60
# $0.07531
# 9,452,950 FTC
# FTC
# 9,452,950
# Terracoin
# $519,200.27
# $0.167
# 3,108,670 TRC
# TRC
# 3,108,670
# Devcoin
# $276,948.24
# $0.00005741
# 4,823,869,952 DVC
# DVC
# 4,823,869,952
# Freicoin
# $223,994.42
# $0.01007
# 22,244,892 FRC
# FRC
# 22,244,892
# Yacoin
# $108,880.76
# $0.02572
# 4,232,722 YAC
# YAC
# 4,232,722
# Digitalcoin
# $90,011.67
# $0.02155
# 4,177,233 DGC
# DGC
# 4,177,233
# CHNCoin
# $70,529.30
# $0.01342
# 5,255,146 CNC
# CNC
# 5,255,146
# BBQCoin
# $65,506.03
# $0.003228
# 20,289,954 BQC
# BQC
# 20,289,954
# WorldCoin
# $56,083.13
# $0.005711
# 9,819,541 WDC
# WDC
# 9,819,541
# Ixcoin
# $46,861.08
# $0.003335
# 14,050,802 IXC *
# IXC
# 14,050,802
# Megacoin
# $38,199.20
# $0.00314
# 12,166,250 MEC
# MEC
# 12,166,250
# Mincoin
# $34,857.44
# $0.02992
# 1,165,200 MNC
# MNC
# 1,165,200
# Phoenixcoin
# $34,584.63
# $0.01186
# 2,917,250 PXC
# PXC
# 2,917,250
# Bitgem
# $25,588.54
# $1.46
# 17,528 BTG
# BTG
# 17,528
# BitBar
# $15,340.53
# $3.73
# 4,115 BTB
# BTB
# 4,115
# 38
# Bitcoin
# $1,080,918,189.52
# $94.69
# 11,415,175 BTC
# BTC
# 11,415,175
# Litecoin
# $56,527,626.50
# $2.91
# 19,438,854 LTC
# LTC
# 19,438,854
# Namecoin
# $3,241,516.48
# $0.5397
# 6,005,693 NMC
# NMC
# 6,005,693
# Peercoin
# $3,141,319.74
# $0.16
# 19,629,768 PPC
# PPC
# 19,629,768
# Novacoin
# $1,230,893.18
# $3.98
# 309,426 NVC
# NVC
# 309,426
# Feathercoin
# $825,730.01
# $0.08238
# 10,023,250 FTC
# FTC
# 10,023,250
# Terracoin
# $497,606.33
# $0.1562
# 3,184,870 TRC
# TRC
# 3,184,870
# Devcoin
# $341,246.54
# $0.00007007
# 4,869,969,920 DVC
# DVC
# 4,869,969,920
# Digitalcoin
# $268,640.90
# $0.05628
# 4,773,045 DGC
# DGC
# 4,773,045
# Freicoin
# $257,105.00
# $0.01136
# 22,626,586 FRC
# FRC
# 22,626,586
# WorldCoin
# $114,748.74
# $0.01032
# 11,116,584 WDC
# WDC
# 11,116,584
# Primecoin
# $112,816.35
# $0.1562
# 722,068 XPM
# XPM
# 722,068
# Yacoin
# $98,606.29
# $0.02263
# 4,357,090 YAC
# YAC
# 4,357,090
# BBQCoin
# $92,091.19
# $0.00445
# 20,692,356 BQC
# BQC
# 20,692,356
# Phoenixcoin
# $70,514.40
# $0.02193
# 3,216,050 PXC
# PXC
# 3,216,050
# Megacoin
# $59,963.61
# $0.004929
# 12,166,250 MEC
# MEC
# 12,166,250
# Ixcoin
# $51,164.72
# $0.003614
# 14,155,922 IXC *
# IXC
# 14,155,922
# CHNCoin
# $49,271.49
# $0.009374
# 5,255,938 CNC
# CNC
# 5,255,938
# Mincoin
# $26,893.62
# $0.02274
# 1,182,798 MNC
# MNC
# 1,182,798
# Luckycoin
# $21,326.13
# $0.003882
# 5,493,104 LKY
# LKY
# 5,493,104
# 42
# Bitcoin
# $1,038,799,169.95
# $90.76
# 11,445,900 BTC
# BTC
# 11,445,900
# Litecoin
# $57,116,054.34
# $2.92
# 19,586,904 LTC
# LTC
# 19,586,904
# Namecoin
# $2,962,845.61
# $0.4883
# 6,067,993 NMC
# NMC
# 6,067,993
# Peercoin
# $2,753,787.82
# $0.1398
# 19,702,806 PPC
# PPC
# 19,702,806
# Novacoin
# $1,204,790.03
# $3.85
# 312,791 NVC
# NVC
# 312,791
# Primecoin
# $1,168,854.58
# $1.04
# 1,119,905 XPM
# XPM
# 1,119,905
# Feathercoin
# $882,015.91
# $0.08077
# 10,919,550 FTC
# FTC
# 10,919,550
# Terracoin
# $487,870.61
# $0.1497
# 3,257,910 TRC
# TRC
# 3,257,910
# Devcoin
# $254,344.99
# $0.00005173
# 4,916,620,288 DVC
# DVC
# 4,916,620,288
# Freicoin
# $244,976.19
# $0.01078
# 22,717,088 FRC
# FRC
# 22,717,088
# Digitalcoin
# $170,031.29
# $0.03181
# 5,345,141 DGC
# DGC
# 5,345,141
# Megacoin
# $161,426.39
# $0.01232
# 13,101,500 MEC
# MEC
# 13,101,500
# WorldCoin
# $145,792.15
# $0.0118
# 12,356,888 WDC
# WDC
# 12,356,888
# Phoenixcoin
# $126,115.75
# $0.03694
# 3,414,150 PXC
# PXC
# 3,414,150
# Yacoin
# $81,633.98
# $0.0177
# 4,612,695 YAC
# YAC
# 4,612,695
# BBQCoin
# $77,919.22
# $0.003694
# 21,094,464 BQC
# BQC
# 21,094,464
# CHNCoin
# $62,014.01
# $0.0118
# 5,256,114 CNC
# CNC
# 5,256,114
# Fastcoin
# $55,913.27
# $0.004533
# 12,333,824 FST
# FST
# 12,333,824
# Ixcoin
# $55,740.50
# $0.003904
# 14,276,402 IXC *
# IXC
# 14,276,402
# Mincoin
# $46,706.59
# $0.0389
# 1,200,783 MNC
# MNC
# 1,200,783
# 47
# Bitcoin
# $1,144,602,625.00
# $99.76
# 11,474,025 BTC
# BTC
# 11,474,025
# Litecoin
# $59,091,798.36
# $2.98
# 19,844,180 LTC
# LTC
# 19,844,180
# Namecoin
# $3,755,531.57
# $0.6135
# 6,121,493 NMC
# NMC
# 6,121,493
# Peercoin
# $2,721,121.82
# $0.1377
# 19,766,366 PPC
# PPC
# 19,766,366
# Novacoin
# $1,976,019.96
# $6.01
# 328,773 NVC
# NVC
# 328,773
# Feathercoin
# $1,013,854.40
# $0.08781
# 11,546,500 FTC
# FTC
# 11,546,500
# Primecoin
# $904,374.13
# $0.7232
# 1,250,464 XPM
# XPM
# 1,250,464
# Terracoin
# $461,230.76
# $0.1317
# 3,500,890 TRC
# TRC
# 3,500,890
# Devcoin
# $267,289.84
# $0.00005387
# 4,961,920,000 DVC
# DVC
# 4,961,920,000
# Freicoin
# $208,635.46
# $0.009078
# 22,983,058 FRC
# FRC
# 22,983,058
# Digitalcoin
# $177,525.47
# $0.02993
# 5,931,793 DGC
# DGC
# 5,931,793
# Megacoin
# $153,304.26
# $0.009974
# 15,371,000 MEC
# MEC
# 15,371,000
# WorldCoin
# $108,739.11
# $0.007982
# 13,622,232 WDC
# WDC
# 13,622,232
# Phoenixcoin
# $94,141.07
# $0.02715
# 3,467,750 PXC
# PXC
# 3,467,750
# Yacoin
# $84,116.05
# $0.01726
# 4,874,093 YAC
# YAC
# 4,874,093
# Fastcoin
# $72,306.80
# $0.005187
# 13,939,168 FST
# FST
# 13,939,168
# BBQCoin
# $64,771.61
# $0.003013
# 21,500,016 BQC
# BQC
# 21,500,016
# Ixcoin
# $56,788.95
# $0.003946
# 14,390,258 IXC *
# IXC
# 14,390,258
# Infinitecoin
# $48,077.50
# $0.0000007742
# 62,102,962,176 IFC
# IFC
# 62,102,962,176
# Franko
# $46,265.64
# $1.05
# 44,170 FRK
# FRK
# 44,170
# 50
# Bitcoin
# $1,209,792,869.08
# $105.14
# 11,506,100 BTC
# BTC
# 11,506,100
# Litecoin
# $60,288,260.68
# $3.01
# 20,034,580 LTC
# LTC
# 20,034,580
# XRP
# $45,983,543.33
# $0.005882
# 7,817,889,792 XRP *
# XRP
# 7,817,889,792
# Namecoin
# $3,844,310.07
# $0.6214
# 6,186,543 NMC
# NMC
# 6,186,543
# Peercoin
# $3,194,186.00
# $0.1609
# 19,855,732 PPC
# PPC
# 19,855,732
# Feathercoin
# $2,066,053.89
# $0.1661
# 12,436,600 FTC
# FTC
# 12,436,600
# Novacoin
# $1,855,987.14
# $5.46
# 340,114 NVC
# NVC
# 340,114
# Primecoin
# $889,983.29
# $0.6487
# 1,371,864 XPM
# XPM
# 1,371,864
# Terracoin
# $596,396.30
# $0.1693
# 3,523,110 TRC
# TRC
# 3,523,110
# Devcoin
# $321,340.28
# $0.00006414
# 5,010,169,856 DVC
# DVC
# 5,010,169,856
# Digitalcoin
# $227,201.16
# $0.03529
# 6,438,044 DGC
# DGC
# 6,438,044
# Freicoin
# $158,973.60
# $0.006834
# 23,261,020 FRC
# FRC
# 23,261,020
# WorldCoin
# $123,167.02
# $0.008433
# 14,606,197 WDC
# WDC
# 14,606,197
# Megacoin
# $116,160.07
# $0.007361
# 15,780,250 MEC
# MEC
# 15,780,250
# Yacoin
# $106,721.68
# $0.02061
# 5,178,616 YAC
# YAC
# 5,178,616
# Mincoin
# $90,902.20
# $0.0736
# 1,235,075 MNC
# MNC
# 1,235,075
# Phoenixcoin
# $80,723.76
# $0.02325
# 3,472,400 PXC
# PXC
# 3,472,400
# Fastcoin
# $63,341.24
# $0.004075
# 15,542,464 FST
# FST
# 15,542,464
# BBQCoin
# $63,307.39
# $0.002891
# 21,894,690 BQC
# BQC
# 21,894,690
# Bullion
# $61,609.39
# $0.1122
# 549,336 CBX
# CBX
# 549,336
# 49
# Bitcoin
# $1,211,789,250.00
# $105.00
# 11,540,850 BTC
# BTC
# 11,540,850
# Litecoin
# $54,533,789.26
# $2.69
# 20,240,430 LTC
# LTC
# 20,240,430
# XRP
# $34,518,516.10
# $0.004415
# 7,817,889,792 XRP *
# XRP
# 7,817,889,792
# Namecoin
# $4,222,475.34
# $0.673
# 6,273,643 NMC
# NMC
# 6,273,643
# Peercoin
# $3,159,445.71
# $0.1585
# 19,927,126 PPC
# PPC
# 19,927,126
# Feathercoin
# $2,001,729.80
# $0.1523
# 13,147,650 FTC
# FTC
# 13,147,650
# Novacoin
# $1,799,905.11
# $5.15
# 349,764 NVC
# NVC
# 349,764
# Primecoin
# $1,351,773.92
# $0.8832
# 1,530,619 XPM
# XPM
# 1,530,619
# Terracoin
# $655,735.09
# $0.1806
# 3,630,870 TRC
# TRC
# 3,630,870
# Devcoin
# $286,724.52
# $0.0000567
# 5,056,869,888 DVC
# DVC
# 5,056,869,888
# Digitalcoin
# $212,140.22
# $0.03099
# 6,846,204 DGC
# DGC
# 6,846,204
# Freicoin
# $158,239.86
# $0.006616
# 23,917,574 FRC
# FRC
# 23,917,574
# WorldCoin
# $126,981.80
# $0.00819
# 15,504,492 WDC
# WDC
# 15,504,492
# Yacoin
# $115,933.19
# $0.021
# 5,520,628 YAC
# YAC
# 5,520,628
# Megacoin
# $93,483.78
# $0.005924
# 15,780,250 MEC
# MEC
# 15,780,250
# Mincoin
# $87,569.47
# $0.07005
# 1,250,067 MNC
# MNC
# 1,250,067
# Ixcoin
# $85,022.82
# $0.005784
# 14,698,514 IXC *
# IXC
# 14,698,514
# Infinitecoin
# $80,005.13
# $0.000001133
# 70,605,864,960 IFC
# IFC
# 70,605,864,960
# Bullion
# $75,822.86
# $0.1281
# 591,904 CBX
# CBX
# 591,904
# Phoenixcoin
# $71,820.28
# $0.02068
# 3,472,800 PXC
# PXC
# 3,472,800
# 46
# Bitcoin
# $1,313,544,012.50
# $113.50
# 11,573,075 BTC
# BTC
# 11,573,075
# Litecoin
# $57,197,936.54
# $2.80
# 20,444,080 LTC
# LTC
# 20,444,080
# XRP
# $43,916,495.73
# $0.005617
# 7,817,889,792 XRP *
# XRP
# 7,817,889,792
# Namecoin
# $4,320,531.60
# $0.681
# 6,344,393 NMC
# NMC
# 6,344,393
# Peercoin
# $3,363,135.65
# $0.168
# 20,021,048 PPC
# PPC
# 20,021,048
# Feathercoin
# $2,041,295.25
# $0.1476
# 13,834,600 FTC
# FTC
# 13,834,600
# Novacoin
# $1,890,229.07
# $5.27
# 358,922 NVC
# NVC
# 358,922
# Primecoin
# $1,362,819.31
# $0.8285
# 1,644,834 XPM
# XPM
# 1,644,834
# Terracoin
# $710,540.21
# $0.1952
# 3,639,690 TRC
# TRC
# 3,639,690
# Infinitecoin
# $385,870.29
# $0.000005276
# 73,139,093,504 IFC
# IFC
# 73,139,093,504
# GoldCoin
# $327,067.37
# $0.01264
# 25,879,596 GLC
# GLC
# 25,879,596
# Devcoin
# $289,562.33
# $0.00005675
# 5,102,419,968 DVC
# DVC
# 5,102,419,968
# Digitalcoin
# $251,720.82
# $0.03499
# 7,194,824 DGC
# DGC
# 7,194,824
# Freicoin
# $197,891.11
# $0.008093
# 24,453,494 FRC
# FRC
# 24,453,494
# WorldCoin
# $132,499.67
# $0.008058
# 16,442,226 WDC
# WDC
# 16,442,226
# Yacoin
# $117,999.80
# $0.02077
# 5,681,125 YAC
# YAC
# 5,681,125
# Bullion
# $93,795.56
# $0.1476
# 635,687 CBX
# CBX
# 635,687
# Ixcoin
# $93,476.22
# $0.006305
# 14,825,906 IXC *
# IXC
# 14,825,906
# Megacoin
# $93,152.95
# $0.005903
# 15,780,250 MEC
# MEC
# 15,780,250
# Mincoin
# $93,107.61
# $0.07378
# 1,262,009 MNC
# MNC
# 1,262,009
# 47
# Bitcoin
# $1,417,199,162.92
# $122.11
# 11,605,825 BTC
# BTC
# 11,605,825
# Litecoin
# $53,577,769.50
# $2.59
# 20,657,380 LTC
# LTC
# 20,657,380
# XRP
# $47,719,524.89
# $0.006104
# 7,817,889,792 XRP *
# XRP
# 7,817,889,792
# Namecoin
# $3,939,439.05
# $0.6142
# 6,413,743 NMC
# NMC
# 6,413,743
# Peercoin
# $3,531,624.24
# $0.1758
# 20,084,320 PPC
# PPC
# 20,084,320
# Feathercoin
# $1,885,131.96
# $0.1307
# 14,427,900 FTC
# FTC
# 14,427,900
# Novacoin
# $1,711,800.36
# $4.64
# 369,099 NVC
# NVC
# 369,099
# Primecoin
# $1,298,228.08
# $0.7378
# 1,759,606 XPM
# XPM
# 1,759,606
# Terracoin
# $628,218.78
# $0.1722
# 3,648,690 TRC
# TRC
# 3,648,690
# Infinitecoin
# $435,199.15
# $0.000005807
# 74,946,838,528 IFC
# IFC
# 74,946,838,528
# Devcoin
# $308,306.94
# $0.00005983
# 5,152,670,208 DVC
# DVC
# 5,152,670,208
# Digitalcoin
# $248,936.60
# $0.03297
# 7,550,124 DGC
# DGC
# 7,550,124
# Freicoin
# $211,349.14
# $0.008471
# 24,948,742 FRC
# FRC
# 24,948,742
# GoldCoin
# $170,528.98
# $0.006534
# 26,098,070 GLC
# GLC
# 26,098,070
# WorldCoin
# $114,698.19
# $0.00659
# 17,404,008 WDC
# WDC
# 17,404,008
# Bullion
# $104,095.81
# $0.1526
# 681,969 CBX
# CBX
# 681,969
# Megacoin
# $96,327.85
# $0.006104
# 15,780,250 MEC
# MEC
# 15,780,250
# Yacoin
# $94,940.73
# $0.01587
# 5,980,733 YAC
# YAC
# 5,980,733
# Ixcoin
# $93,650.62
# $0.006229
# 15,034,898 IXC *
# IXC
# 15,034,898
# Anoncoin
# $73,233.32
# $0.1716
# 426,852 ANC
# ANC
# 426,852
# 49
# Bitcoin
# $1,610,215,304.37
# $138.34
# 11,639,550 BTC
# BTC
# 11,639,550
# Litecoin
# $53,930,594.93
# $2.58
# 20,869,430 LTC
# LTC
# 20,869,430
# XRP
# $45,239,802.42
# $0.005787
# 7,817,889,792 XRP *
# XRP
# 7,817,889,792
# Namecoin
# $3,689,125.25
# $0.5686
# 6,488,343 NMC
# NMC
# 6,488,343
# Peercoin
# $3,593,391.71
# $0.1785
# 20,135,716 PPC
# PPC
# 20,135,716
# Feathercoin
# $2,258,187.28
# $0.1508
# 14,975,650 FTC
# FTC
# 14,975,650
# Novacoin
# $1,552,776.08
# $4.07
# 381,781 NVC
# NVC
# 381,781
# Primecoin
# $1,167,915.89
# $0.6225
# 1,876,088 XPM
# XPM
# 1,876,088
# Terracoin
# $668,094.33
# $0.1826
# 3,658,610 TRC
# TRC
# 3,658,610
# Infinitecoin
# $369,518.55
# $0.000004858
# 76,056,100,864 IFC
# IFC
# 76,056,100,864
# Devcoin
# $302,074.70
# $0.0000581
# 5,198,969,856 DVC
# DVC
# 5,198,969,856
# Freicoin
# $214,535.40
# $0.008453
# 25,381,074 FRC
# FRC
# 25,381,074
# Anoncoin
# $174,151.27
# $0.3995
# 435,895 ANC
# ANC
# 435,895
# Digitalcoin
# $163,789.00
# $0.02075
# 7,892,013 DGC
# DGC
# 7,892,013
# Bullion
# $135,838.83
# $0.1868
# 727,332 CBX
# CBX
# 727,332
# GoldCoin
# $134,760.72
# $0.005121
# 26,313,530 GLC
# GLC
# 26,313,530
# Ixcoin
# $113,218.36
# $0.007457
# 15,183,794 IXC *
# IXC
# 15,183,794
# Megacoin
# $106,957.77
# $0.006087
# 17,571,624 MEC
# MEC
# 17,571,624
# Mincoin
# $91,338.40
# $0.07071
# 1,291,813 MNC
# MNC
# 1,291,813
# Memecoin
# $91,218.32
# $0.002891
# 31,548,150 MEM
# MEM
# 31,548,150
# 47
# Bitcoin
# $1,419,836,114.24
# $121.66
# 11,670,525 BTC
# BTC
# 11,670,525
# Litecoin
# $57,470,295.67
# $2.73
# 21,069,780 LTC
# LTC
# 21,069,780
# XRP
# $48,338,335.15
# $0.006183
# 7,817,889,792 XRP *
# XRP
# 7,817,889,792
# Namecoin
# $3,845,497.84
# $0.5864
# 6,557,793 NMC
# NMC
# 6,557,793
# Peercoin
# $3,767,600.74
# $0.1861
# 20,240,704 PPC
# PPC
# 20,240,704
# Feathercoin
# $2,074,463.63
# $0.1338
# 15,501,200 FTC
# FTC
# 15,501,200
# Novacoin
# $1,398,183.32
# $3.60
# 388,787 NVC
# NVC
# 388,787
# Primecoin
# $1,015,901.17
# $0.511
# 1,988,179 XPM
# XPM
# 1,988,179
# Terracoin
# $602,556.06
# $0.163
# 3,696,110 TRC
# TRC
# 3,696,110
# Bullion
# $255,979.70
# $0.3406
# 751,449 CBX
# CBX
# 751,449
# Devcoin
# $242,525.39
# $0.00004623
# 5,245,969,920 DVC
# DVC
# 5,245,969,920
# Infinitecoin
# $231,032.16
# $0.00000302
# 76,503,580,672 IFC
# IFC
# 76,503,580,672
# Freicoin
# $174,527.94
# $0.006691
# 26,082,816 FRC
# FRC
# 26,082,816
# Digitalcoin
# $169,894.36
# $0.02053
# 8,275,369 DGC
# DGC
# 8,275,369
# Memecoin
# $143,212.53
# $0.004261
# 33,606,952 MEM
# MEM
# 33,606,952
# Ixcoin
# $106,165.94
# $0.006935
# 15,309,554 IXC *
# IXC
# 15,309,554
# GoldCoin
# $103,550.51
# $0.003903
# 26,532,004 GLC
# GLC
# 26,532,004
# Megacoin
# $102,276.61
# $0.005664
# 18,055,750 MEC
# MEC
# 18,055,750
# WorldCoin
# $86,001.08
# $0.004449
# 19,329,968 WDC
# WDC
# 19,329,968
# Mincoin
# $71,430.79
# $0.05475
# 1,304,743 MNC
# MNC
# 1,304,743
# 354
# 354
# 354
# 354
# 354
# ['Bitcoin', 'Litecoin', 'Peercoin', 'Namecoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Feathercoin', 'Freicoin', 'Terracoin', 'Devcoin', 'Novacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Devcoin', 'Terracoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'BBQCoin', 'Ixcoin', 'BitBar', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Devcoin', 'Terracoin', 'Freicoin', 'Feathercoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BBQCoin', 'WorldCoin', 'BitBar', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Devcoin', 'Terracoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Ixcoin', 'Mincoin', 'BBQCoin', 'BitBar', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Freicoin', 'CHNCoin', 'BBQCoin', 'Yacoin', 'Digitalcoin', 'WorldCoin', 'BitBar', 'Mincoin', 'Memecoin', 'AmericanCoin', 'Franko', 'Elacoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Freicoin', 'CHNCoin', 'BBQCoin', 'Digitalcoin', 'Yacoin', 'WorldCoin', 'Mincoin', 'BitBar', 'GoldCoin', 'Memecoin', 'Luckycoin', 'Franko', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Freicoin', 'CHNCoin', 'Digitalcoin', 'Yacoin', 'BBQCoin', 'Ixcoin', 'WorldCoin', 'BitBar', 'Mincoin', 'GoldCoin', 'Memecoin', 'Bytecoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Freicoin', 'Digitalcoin', 'Yacoin', 'BBQCoin', 'WorldCoin', 'Ixcoin', 'CHNCoin', 'Mincoin', 'BitBar', 'Luckycoin', 'Memecoin', 'GoldCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Freicoin', 'Yacoin', 'Digitalcoin', 'CHNCoin', 'BBQCoin', 'WorldCoin', 'Ixcoin', 'Megacoin', 'Mincoin', 'Phoenixcoin', 'Bitgem', 'BitBar', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Digitalcoin', 'Freicoin', 'WorldCoin', 'Primecoin', 'Yacoin', 'BBQCoin', 'Phoenixcoin', 'Megacoin', 'Ixcoin', 'CHNCoin', 'Mincoin', 'Luckycoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Primecoin', 'Feathercoin', 'Terracoin', 'Devcoin', 'Freicoin', 'Digitalcoin', 'Megacoin', 'WorldCoin', 'Phoenixcoin', 'Yacoin', 'BBQCoin', 'CHNCoin', 'Fastcoin', 'Ixcoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Feathercoin', 'Primecoin', 'Terracoin', 'Devcoin', 'Freicoin', 'Digitalcoin', 'Megacoin', 'WorldCoin', 'Phoenixcoin', 'Yacoin', 'Fastcoin', 'BBQCoin', 'Ixcoin', 'Infinitecoin', 'Franko', 'Bitcoin', 'Litecoin', 'XRP', 'Namecoin', 'Peercoin', 'Feathercoin', 'Novacoin', 'Primecoin', 'Terracoin', 'Devcoin', 'Digitalcoin', 'Freicoin', 'WorldCoin', 'Megacoin', 'Yacoin', 'Mincoin', 'Phoenixcoin', 'Fastcoin', 'BBQCoin', 'Bullion', 'Bitcoin', 'Litecoin', 'XRP', 'Namecoin', 'Peercoin', 'Feathercoin', 'Novacoin', 'Primecoin', 'Terracoin', 'Devcoin', 'Digitalcoin', 'Freicoin', 'WorldCoin', 'Yacoin', 'Megacoin', 'Mincoin', 'Ixcoin', 'Infinitecoin', 'Bullion', 'Phoenixcoin', 'Bitcoin', 'Litecoin', 'XRP', 'Namecoin', 'Peercoin', 'Feathercoin', 'Novacoin', 'Primecoin', 'Terracoin', 'Infinitecoin', 'GoldCoin', 'Devcoin', 'Digitalcoin', 'Freicoin', 'WorldCoin', 'Yacoin', 'Bullion', 'Ixcoin', 'Megacoin', 'Mincoin', 'Bitcoin', 'Litecoin', 'XRP', 'Namecoin', 'Peercoin', 'Feathercoin', 'Novacoin', 'Primecoin', 'Terracoin', 'Infinitecoin', 'Devcoin', 'Digitalcoin', 'Freicoin', 'GoldCoin', 'WorldCoin', 'Bullion', 'Megacoin', 'Yacoin', 'Ixcoin', 'Anoncoin', 'Bitcoin', 'Litecoin', 'XRP', 'Namecoin', 'Peercoin', 'Feathercoin', 'Novacoin', 'Primecoin', 'Terracoin', 'Infinitecoin', 'Devcoin', 'Freicoin', 'Anoncoin', 'Digitalcoin', 'Bullion', 'GoldCoin', 'Ixcoin', 'Megacoin', 'Mincoin', 'Memecoin',  ...
# [['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], ['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], ['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], ['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], ['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], ['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], ['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], ['Bitcoin', '$1,288,693,216.22', '$115.91', '11,118,050', 'BTC'], ['Litecoin', '$62,298,217.32', '$3.59', '17,348,954', 'LTC'], ['Namecoin', '$6,290,543.05', '$1.15', '5,465,350', 'NMC'], ['Peercoin', '$5,718,446.46', '$0.3037', '18,830,240', 'PPC'], ['Feathercoin', '$2,017,436.23', '$0.313', '6,444,650', 'FTC'], ['Freicoin', '$1,627,438.51', '$0.08114', '20,057,908', 'FRC'], ['Terracoin', '$1,367,162.39', '$0.568', '2,407,150', 'TRC'], ['Devcoin', '$1,052,081.53', '$0.0002388', '4,406,170,112', 'DVC'], ['Novacoin', '$1,015,804.46', '$3.69', '275,503', 'NVC'], ['Mincoin', '$118,657.23', '$0.1159', '1,023,701', 'MNC'], ['Bitcoin', '$1,281,982,625.00', '$115.00', '11,147,675', 'BTC'], ['Litecoin', '$57,513,319.09', '$3.27', '17,591,130', 'LTC'], ['Namecoin', '$4,674,413.40', '$0.8464', '5,522,700', 'NMC'], ['Peercoin', '$4,585,556.07', '$0.2427', '18,897,820', 'PPC'], ['Novacoin', '$984,531.38', '$3.52', '279,685', 'NVC'], ['Devcoin', '$983,447.61', '$0.0002208', '4,454,020,096', 'DVC'], ['Terracoin', '$954,262.84', '$0.3807', '2,506,930', 'TRC'], ['Feathercoin', '$820,221.45', '$0.1253', '6,543,450', 'FTC'], ['Freicoin', '$748,241.76', '$0.03596', '20,807,988', 'FRC'], ['CHNCoin', '$489,370.40', '$0.0966', '5,065,946', 'CNC'], ['Mincoin', '$247,203.65', '$0.237', '1,042,987', 'MNC'], ['BBQCoin', '$156,410.47', '$0.0092', '17,001,138', 'BQC'], ['Ixcoin', '$147,029.97', '$0.01162', '12,653,618', 'IXC'], ['BitBar', '$82,905.80', '$28.86', '2,872', 'BTB'], ['Bitcoin', '$1,363,205,019.90', '$121.99', '11,174,725', 'BTC'], ['Litecoin', '$58,760,675.05', '$3.30', '17,787,454', 'LTC'], ['Namecoin', '$4,789,082.16', '$0.8576', '5,584,350', 'NMC'], ['Peercoin', '$3,934,412.36', '$0.2074', '18,971,716', 'PPC'], ['Novacoin', '$1,020,004.70', '$3.62', '281,908', 'NVC'], ['Terracoin', '$934,991.48', '$0.3587', '2,606,970', 'TRC'], ['Devcoin', '$906,212.77', '$0.0002013', '4,502,170,112', 'DVC'], ['Feathercoin', '$833,818.95', '$0.1269', '6,572,250', 'FTC'], ['Freicoin', '$711,435.19', '$0.03416', '20,827,516', 'FRC'], ['CHNCoin', '$485,058.81', '$0.09515', '5,097,714', 'CNC'], ['Mincoin', '$207,096.26', '$0.1952', '1,061,031', 'MNC'], ['Ixcoin', '$154,515.88', '$0.01221', '12,653,618', 'IXC'], ['BitBar', '$128,439.08', '$42.70', '3,008', 'BTB'], ['BBQCoin', '$123,231.29', '$0.007075', '17,416,812', 'BQC'], ['Bitcoin', '$1,495,292,967.14', '$133.48', '11,202,375', 'BTC'], ['Litecoin', '$58,458,016.95', '$3.25', '17,993,154', 'LTC'], ['Namecoin', '$5,251,485.27', '$0.9304', '5,644,600', 'NMC'], ['Peercoin', '$3,612,498.62', '$0.1895', '19,059,134', 'PPC'], ['Novacoin', '$1,225,595.40', '$4.31', '284,444', 'NVC'], ['Devcoin', '$915,607.00', '$0.0002016', '4,542,720,000', 'DVC'], ['Terracoin', '$842,448.90', '$0.3123', '2,697,190', 'TRC'], ['Freicoin', '$687,220.00', '$0.0327', '21,014,232', 'FRC'], ['Feathercoin', '$654,331.38', '$0.09878', '6,624,450', 'FTC'], ['CHNCoin', '$374,915.45', '$0.07341', '5,106,866', 'CNC'], ['Mincoin', '$130,393.11', '$0.1218', '1,070,899', 'MNC'], ['Ixcoin', '$127,367.86', '$0.01007', '12,653,618', 'IXC'], ['BBQCoin', '$114,258.29', '$0.006407', '17,833,240', 'BQC'], ['WorldCoin', '$61,369.21', '$0.02565', '2,392,562', 'WDC'], ['BitBar', '$54,030.08', '$17.36', '3,113', 'BTB'], ['Bitcoin', '$1,373,839,383.45', '$122.29', '11,234,075', 'BTC'], ['Litecoin', '$49,625,738.78', '$2.73', '18,197,154', 'LTC'], ['Namecoin', '$4,038,794.14', '$0.7093', '5,694,100', 'NMC'], ['Peercoin', '$2,899,779.44', '$0.1516', '19,122,498', 'PPC'], ['Novacoin', '$1,117,980.01', '$3.90', '286,310', 'NVC'] ...
# [[['Bitcoin', '$1,488,566,971.96', '$134.21', '11,091,325', 'BTC'], 'https://coinmarketcap.com/historical/20130428/'], [['Litecoin', '$74,637,021.57', '$4.35', '17,164,230', 'LTC'], 'https://coinmarketcap.com/historical/20130505/'], [['Peercoin', '$7,250,186.65', '$0.3865', '18,757,362', 'PPC'], 'https://coinmarketcap.com/historical/20130512/'], [['Namecoin', '$5,995,997.19', '$1.11', '5,415,300', 'NMC'], 'https://coinmarketcap.com/historical/20130519/'], [['Terracoin', '$1,503,099.40', '$0.6469', '2,323,570', 'TRC'], 'https://coinmarketcap.com/historical/20130526/'], [['Devcoin', '$1,424,087.30', '$0.0003261', '4,366,620,160', 'DVC'], 'https://coinmarketcap.com/historical/20130602/'], [['Novacoin', '$1,162,266.30', '$4.25', '273,706', 'NVC'], 'https://coinmarketcap.com/historical/20130609/'], [['Bitcoin', '$1,288,693,216.22', '$115.91', '11,118,050', 'BTC'], 'https://coinmarketcap.com/historical/20130616/'], [['Litecoin', '$62,298,217.32', '$3.59', '17,348,954', 'LTC'], 'https://coinmarketcap.com/historical/20130623/'], [['Namecoin', '$6,290,543.05', '$1.15', '5,465,350', 'NMC'], 'https://coinmarketcap.com/historical/20130630/'], [['Peercoin', '$5,718,446.46', '$0.3037', '18,830,240', 'PPC'], 'https://coinmarketcap.com/historical/20130707/'], [['Feathercoin', '$2,017,436.23', '$0.313', '6,444,650', 'FTC'], 'https://coinmarketcap.com/historical/20130714/'], [['Freicoin', '$1,627,438.51', '$0.08114', '20,057,908', 'FRC'], 'https://coinmarketcap.com/historical/20130721/'], [['Terracoin', '$1,367,162.39', '$0.568', '2,407,150', 'TRC'], 'https://coinmarketcap.com/historical/20130728/'], [['Devcoin', '$1,052,081.53', '$0.0002388', '4,406,170,112', 'DVC'], 'https://coinmarketcap.com/historical/20130804/'], [['Novacoin', '$1,015,804.46', '$3.69', '275,503', 'NVC'], 'https://coinmarketcap.com/historical/20130811/'], [['Mincoin', '$118,657.23', '$0.1159', '1,023,701', 'MNC'], 'https://coinmarketcap.com/historical/20130818/'], [['Bitcoin', '$1,281,982,625.00', '$115.00', '11,147,675', 'BTC'], 'https://coinmarketcap.com/historical/20130825/'], [['Litecoin', '$57,513,319.09', '$3.27', '17,591,130', 'LTC'], 'https://coinmarketcap.com/historical/20130901/'], [['Namecoin', '$4,674,413.40', '$0.8464', '5,522,700', 'NMC'], 'https://coinmarketcap.com/historical/20130908/'], [['Peercoin', '$4,585,556.07', '$0.2427', '18,897,820', 'PPC'], 'https://coinmarketcap.com/historical/20130915/'], [['Novacoin', '$984,531.38', '$3.52', '279,685', 'NVC'], 'https://coinmarketcap.com/historical/20130922/'], [['Devcoin', '$983,447.61', '$0.0002208', '4,454,020,096', 'DVC'], 'https://coinmarketcap.com/historical/20130929/'], [['Terracoin', '$954,262.84', '$0.3807', '2,506,930', 'TRC'], 'https://coinmarketcap.com/historical/20131006/'], [['Feathercoin', '$820,221.45', '$0.1253', '6,543,450', 'FTC'], 'https://coinmarketcap.com/historical/20131013/'], [['Freicoin', '$748,241.76', '$0.03596', '20,807,988', 'FRC'], 'https://coinmarketcap.com/historical/20131020/'], [['CHNCoin', '$489,370.40', '$0.0966', '5,065,946', 'CNC'], 'https://coinmarketcap.com/historical/20131027/'], [['Mincoin', '$247,203.65', '$0.237', '1,042,987', 'MNC'], 'https://coinmarketcap.com/historical/20131103/'], [['BBQCoin', '$156,410.47', '$0.0092', '17,001,138', 'BQC'], 'https://coinmarketcap.com/historical/20131110/'], [['Ixcoin', '$147,029.97', '$0.01162', '12,653,618', 'IXC'], 'https://coinmarketcap.com/historical/20131117/'], [['BitBar', '$82,905.80', '$28.86', '2,872', 'BTB'], 'https://coinmarketcap.com/historical/20131124/'], [['Bitcoin', '$1,363,205,019.90', '$121.99', '11,174,725', 'BTC'], 'https://coinmarketcap.com/historical/20131201/'], [['Litecoin', '$58,760,675.05', '$3.30', '17,787,454', 'LTC'], 'https://coinmarketcap.com/historical/20131208/'], [['Namecoin', '$4,789,082.16', '$0.8576', '5,584,350', 'NMC'], 'https://coinmarketcap.com/historical/20131215/'], [['Peercoin', '$3,934,412.36', '$0.2074', '18,971,716', 'PPC'], 'https://coinmarketcap.com/historical/20131222/'], [['Novacoi ...

# %% [markdown]
# Try to call the class functions above to the below scraping code

# %%
#create function to scrape data
#example = https://coinmarketcap.com/historical/20220703/'
def crypto_scrape():
    #creating empty lists with which to store data later
    crypto_name_list = []
    crypto_market_cap_list = []
    crypto_price_list = []
    crypto_circulating_supply_list = []
    crypto_ticker_list = []
    
    #creating a data frame for later
    df = pd.DataFrame()
    
    #define url and vary permalink depending on the date
    url = 'https://coinmarketcap.com/historical/20220703'
    
    #request webpage
    webpage = requests.get(url)
    
    #parse the html
    soup = BeautifulSoup(webpage.text, 'html.parser')
   
    #create a variable for the table rows (tr)
    tr = soup.find_all('tr', attrs={'class':'cmc-table-row'})
    
    #creating a counter to iterate through first 10 rows (top 10 cryptocurrencies)
    count = 0
    
    #iterate through the first 10 rows
    for row in tr:
        if count == 10:
            break
        count = count + 1

    #store the name of the coin as a variable by finding td element (column) 
        name_column = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sticky cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--sort-by__name'})
        #find the column within the row and strip the text
        crypto_name = name_column.find('a', attrs={'class': 'cmc-table__column-name--name cmc-link'}).text.strip()
        print(crypto_name)

        #find and createvvariable for market cap
        crypto_market_cap = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__market-cap'}).text.strip()
        print(crypto_market_cap)

        #Find and create variable for the price
        crypto_price = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__price'}).text.strip()
        print(crypto_price)
        #Find and create variable for the circulating supply
        crypto_circulating_supply_and_ticker = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__circulating-supply'}).text.strip()
        print(crypto_circulating_supply_and_ticker)
        #Find and create variable for the circulating supply by splitting the supply+ticker variable
        crypto_ticker = crypto_circulating_supply_and_ticker.split(' ')[1]
        print(crypto_ticker)
        #Find and create variable for the coin ticker
        crypto_circulating_supply = crypto_circulating_supply_and_ticker.split(' ')[0]
        print(crypto_circulating_supply)
        

        #append the data to the associated lists
        crypto_name_list.append(crypto_name)
        crypto_market_cap_list.append(crypto_market_cap)
        crypto_price_list.append(crypto_price)
        crypto_circulating_supply_list.append(crypto_circulating_supply)
        crypto_ticker_list.append(crypto_ticker)

#run the function with a nominated date
crypto_scrape()

# %%
#store the data in a dataframe to make it structured
df['Name'] = crypto_name_list
df['Market cap'] = crypto_market_cap_list
df['Price'] = crypto_price_list
df['Circulating supply'] = crypto_circulating_supply_list
df['Ticker'] = crypto_ticker_list

#show the data
df
# Out:
#           Name           Market cap       Price Circulating supply Ticker
# 0      Bitcoin  $368,272,636,367.55  $19,297.08         19,084,375    BTC
# 1     Ethereum  $130,354,920,626.22   $1,073.77        121,399,635    ETH
# 2       Tether   $66,169,266,578.19     $0.9991     66,230,318,610   USDT
# 3     USD Coin   $55,823,349,220.82       $1.00     55,802,605,113   USDC
# 4          BNB   $35,754,443,110.53     $218.98        163,276,975    BNB
# 5  Binance USD   $17,534,713,957.66     $0.9993     17,547,224,379   BUSD
# 6          XRP   $15,552,125,745.52     $0.3217     48,343,101,197    XRP
# 7      Cardano   $15,377,222,959.95     $0.4556     33,752,565,071    ADA
# 8       Solana   $11,465,283,748.49      $33.39        343,416,618    SOL
# 9     Dogecoin    $8,912,747,929.92    $0.06718    132,670,764,300   DOGE

# %% [markdown]
# instead of generating multiple URLs ahead of time, this code uses selenium to click "next page" to extract the data

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import requests
import time


# function to use Selenium to iteratively click next pages and store data daily and as a compiled list
def click_next_week():
    
    driver.get('https://coinmarketcap.com/historical/20130519/')

    time.sleep(2) # Delay to avoid looking like a bot to server
 

    #parsing html to Beautiful Soup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

   #creating empty lists with which to store one day's worth of data later
    crypto_name_list_one_day = []
    crypto_market_cap_list_one_day = []
    crypto_price_list_one_day = []
    crypto_circulating_supply_list_one_day = []
    crypto_ticker_list_one_day = []

#creating empty lists with which to store all of the daily data
    crypto_name_list = []
    crypto_market_cap_list = []
    crypto_price_list = []
    crypto_circulating_supply_list = []
    crypto_ticker_list = []
    
    



    num_pages = 5

  
    
    
    #page click counter
    page_click_counter = 0
    #creating while loop to click a certain number of pages
    while (page_click_counter < num_pages):
        count = 0
        next_week_button = driver.find_element(by=By.XPATH, value= '//*[@id="__next"]/div[1]/div[2]/div/div[1]/div[2]/div[2]/a[2]')
        
        next_week_button.click()
        
        print('button_clicked')

        

        #create a variable for the table rows (tr)
        tr = soup.find_all('tr', attrs={'class':'cmc-table-row'})
    #iterate through the first 10 rows
        
        while count < 10:
            
               
            
            # increase the counter for appending rows within 1 day
            
            for row in tr:
    #store the name of the coin as a variable by finding td element (column) 
                name_column = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sticky cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--sort-by__name'})
                #find the column within the row and strip the text
                crypto_name = name_column.find('a', attrs={'class': 'cmc-table__column-name--name cmc-link'}).text.strip()
                print(crypto_name)

                #find and createvvariable for market cap
                crypto_market_cap = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__market-cap'}).text.strip()
                print(crypto_market_cap)

                #Find and create variable for the price
                crypto_price = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__price'}).text.strip()
                print(crypto_price)
                #Find and create variable for the circulating supply
                crypto_circulating_supply_and_ticker = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__circulating-supply'}).text.strip()
                print(crypto_circulating_supply_and_ticker)
                #Find and create variable for the circulating supply by splitting the supply+ticker variable
                crypto_ticker = crypto_circulating_supply_and_ticker.split(' ')[1]
                print(crypto_ticker)
                #Find and create variable for the coin ticker
                crypto_circulating_supply = crypto_circulating_supply_and_ticker.split(' ')[0]
                print(crypto_circulating_supply)
                

                #append the data to the associated lists
                crypto_name_list_one_day.append(crypto_name)
                crypto_market_cap_list_one_day.append(crypto_market_cap)
                crypto_price_list_one_day.append(crypto_price)
                crypto_circulating_supply_list_one_day.append(crypto_circulating_supply)
                crypto_ticker_list_one_day.append(crypto_ticker)
                
                count = count +1
            

        crypto_name_list.append(crypto_name_list_one_day)
        
        crypto_market_cap_list.append(crypto_market_cap_list_one_day)
        
        crypto_price_list.append(crypto_price_list_one_day)
     
        crypto_circulating_supply_list.append(crypto_circulating_supply_list_one_day)
      
        crypto_ticker_list.append(crypto_ticker_list_one_day)
        

        next_week_button = driver.find_element(by=By.XPATH, value= '//*[@id="__next"]/div[1]/div[2]/div/div[1]/div[2]/div[2]/a[2]')
        next_week_button.click()
        
    
        page_click_counter += 1 
  
    print(crypto_name_list)
   
    print(crypto_market_cap_list)

    print(crypto_price_list)

    print(crypto_circulating_supply_list)
 
    print(crypto_ticker_list)
click_next_week()
# Out:
# C:\Users\marko\AppData\Local\Temp\ipykernel_13676\4255216893.py:17: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)
# button_clicked
# Bitcoin
# $1,363,205,019.90
# $121.99
# 11,174,725 BTC
# BTC
# 11,174,725
# Litecoin
# $58,760,675.05
# $3.30
# 17,787,454 LTC
# LTC
# 17,787,454
# Namecoin
# $4,789,082.16
# $0.8576
# 5,584,350 NMC
# NMC
# 5,584,350
# Peercoin
# $3,934,412.36
# $0.2074
# 18,971,716 PPC
# PPC
# 18,971,716
# Novacoin
# $1,020,004.70
# $3.62
# 281,908 NVC
# NVC
# 281,908
# Terracoin
# $934,991.48
# $0.3587
# 2,606,970 TRC
# TRC
# 2,606,970
# Devcoin
# $906,212.77
# $0.0002013
# 4,502,170,112 DVC
# DVC
# 4,502,170,112
# Feathercoin
# $833,818.95
# $0.1269
# 6,572,250 FTC
# FTC
# 6,572,250
# Freicoin
# $711,435.19
# $0.03416
# 20,827,516 FRC
# FRC
# 20,827,516
# CHNCoin
# $485,058.81
# $0.09515
# 5,097,714 CNC
# CNC
# 5,097,714
# Mincoin
# $207,096.26
# $0.1952
# 1,061,031 MNC
# MNC
# 1,061,031
# Ixcoin
# $154,515.88
# $0.01221
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $128,439.08
# $42.70
# 3,008 BTB
# BTB
# 3,008
# BBQCoin
# $123,231.29
# $0.007075
# 17,416,812 BQC
# BQC
# 17,416,812
# button_clicked
# Bitcoin
# $1,363,205,019.90
# $121.99
# 11,174,725 BTC
# BTC
# 11,174,725
# Litecoin
# $58,760,675.05
# $3.30
# 17,787,454 LTC
# LTC
# 17,787,454
# Namecoin
# $4,789,082.16
# $0.8576
# 5,584,350 NMC
# NMC
# 5,584,350
# Peercoin
# $3,934,412.36
# $0.2074
# 18,971,716 PPC
# PPC
# 18,971,716
# Novacoin
# $1,020,004.70
# $3.62
# 281,908 NVC
# NVC
# 281,908
# Terracoin
# $934,991.48
# $0.3587
# 2,606,970 TRC
# TRC
# 2,606,970
# Devcoin
# $906,212.77
# $0.0002013
# 4,502,170,112 DVC
# DVC
# 4,502,170,112
# Feathercoin
# $833,818.95
# $0.1269
# 6,572,250 FTC
# FTC
# 6,572,250
# Freicoin
# $711,435.19
# $0.03416
# 20,827,516 FRC
# FRC
# 20,827,516
# CHNCoin
# $485,058.81
# $0.09515
# 5,097,714 CNC
# CNC
# 5,097,714
# Mincoin
# $207,096.26
# $0.1952
# 1,061,031 MNC
# MNC
# 1,061,031
# Ixcoin
# $154,515.88
# $0.01221
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $128,439.08
# $42.70
# 3,008 BTB
# BTB
# 3,008
# BBQCoin
# $123,231.29
# $0.007075
# 17,416,812 BQC
# BQC
# 17,416,812
# button_clicked
# Bitcoin
# $1,363,205,019.90
# $121.99
# 11,174,725 BTC
# BTC
# 11,174,725
# Litecoin
# $58,760,675.05
# $3.30
# 17,787,454 LTC
# LTC
# 17,787,454
# Namecoin
# $4,789,082.16
# $0.8576
# 5,584,350 NMC
# NMC
# 5,584,350
# Peercoin
# $3,934,412.36
# $0.2074
# 18,971,716 PPC
# PPC
# 18,971,716
# Novacoin
# $1,020,004.70
# $3.62
# 281,908 NVC
# NVC
# 281,908
# Terracoin
# $934,991.48
# $0.3587
# 2,606,970 TRC
# TRC
# 2,606,970
# Devcoin
# $906,212.77
# $0.0002013
# 4,502,170,112 DVC
# DVC
# 4,502,170,112
# Feathercoin
# $833,818.95
# $0.1269
# 6,572,250 FTC
# FTC
# 6,572,250
# Freicoin
# $711,435.19
# $0.03416
# 20,827,516 FRC
# FRC
# 20,827,516
# CHNCoin
# $485,058.81
# $0.09515
# 5,097,714 CNC
# CNC
# 5,097,714
# Mincoin
# $207,096.26
# $0.1952
# 1,061,031 MNC
# MNC
# 1,061,031
# Ixcoin
# $154,515.88
# $0.01221
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $128,439.08
# $42.70
# 3,008 BTB
# BTB
# 3,008
# BBQCoin
# $123,231.29
# $0.007075
# 17,416,812 BQC
# BQC
# 17,416,812
# button_clicked
# Bitcoin
# $1,363,205,019.90
# $121.99
# 11,174,725 BTC
# BTC
# 11,174,725
# Litecoin
# $58,760,675.05
# $3.30
# 17,787,454 LTC
# LTC
# 17,787,454
# Namecoin
# $4,789,082.16
# $0.8576
# 5,584,350 NMC
# NMC
# 5,584,350
# Peercoin
# $3,934,412.36
# $0.2074
# 18,971,716 PPC
# PPC
# 18,971,716
# Novacoin
# $1,020,004.70
# $3.62
# 281,908 NVC
# NVC
# 281,908
# Terracoin
# $934,991.48
# $0.3587
# 2,606,970 TRC
# TRC
# 2,606,970
# Devcoin
# $906,212.77
# $0.0002013
# 4,502,170,112 DVC
# DVC
# 4,502,170,112
# Feathercoin
# $833,818.95
# $0.1269
# 6,572,250 FTC
# FTC
# 6,572,250
# Freicoin
# $711,435.19
# $0.03416
# 20,827,516 FRC
# FRC
# 20,827,516
# CHNCoin
# $485,058.81
# $0.09515
# 5,097,714 CNC
# CNC
# 5,097,714
# Mincoin
# $207,096.26
# $0.1952
# 1,061,031 MNC
# MNC
# 1,061,031
# Ixcoin
# $154,515.88
# $0.01221
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $128,439.08
# $42.70
# 3,008 BTB
# BTB
# 3,008
# BBQCoin
# $123,231.29
# $0.007075
# 17,416,812 BQC
# BQC
# 17,416,812
# button_clicked
# Bitcoin
# $1,363,205,019.90
# $121.99
# 11,174,725 BTC
# BTC
# 11,174,725
# Litecoin
# $58,760,675.05
# $3.30
# 17,787,454 LTC
# LTC
# 17,787,454
# Namecoin
# $4,789,082.16
# $0.8576
# 5,584,350 NMC
# NMC
# 5,584,350
# Peercoin
# $3,934,412.36
# $0.2074
# 18,971,716 PPC
# PPC
# 18,971,716
# Novacoin
# $1,020,004.70
# $3.62
# 281,908 NVC
# NVC
# 281,908
# Terracoin
# $934,991.48
# $0.3587
# 2,606,970 TRC
# TRC
# 2,606,970
# Devcoin
# $906,212.77
# $0.0002013
# 4,502,170,112 DVC
# DVC
# 4,502,170,112
# Feathercoin
# $833,818.95
# $0.1269
# 6,572,250 FTC
# FTC
# 6,572,250
# Freicoin
# $711,435.19
# $0.03416
# 20,827,516 FRC
# FRC
# 20,827,516
# CHNCoin
# $485,058.81
# $0.09515
# 5,097,714 CNC
# CNC
# 5,097,714
# Mincoin
# $207,096.26
# $0.1952
# 1,061,031 MNC
# MNC
# 1,061,031
# Ixcoin
# $154,515.88
# $0.01221
# 12,653,618 IXC *
# IXC
# 12,653,618
# BitBar
# $128,439.08
# $42.70
# 3,008 BTB
# BTB
# 3,008
# BBQCoin
# $123,231.29
# $0.007075
# 17,416,812 BQC
# BQC
# 17,416,812
# [['Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin'], ['Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin'], ['Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin'], ['Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin'], ['Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devcoin', 'Feathercoin', 'Freicoin', 'CHNCoin', 'Mincoin', 'Ixcoin', 'BitBar', 'BBQCoin', 'Bitcoin', 'Litecoin', 'Namecoin', 'Peercoin', 'Novacoin', 'Terracoin', 'Devco ...
# [['$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29'], ['$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29'], ['$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29'], ['$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$207,096.26', '$154,515.88', '$128,439.08', '$123,231.29', '$1,363,205,019.90', '$58,760,675.05', '$4,789,082.16', '$3,934,412.36', '$1,020,004.70', '$934,991.48', '$906,212.77', '$833,818.95', '$711,435.19', '$485,058.81', '$ ...
# [['$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075'], ['$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075'], ['$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075'], ['$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075'], ['$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075', '$121.99', '$3.30', '$0.8576', '$0.2074', '$3.62', '$0.3587', '$0.0002013', '$0.1269', '$0.03416', '$0.09515', '$0.1952', '$0.01221', '$42.70', '$0.007075']]
# [['11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812'], ['11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812'], ['11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812'], ['11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812'], ['11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,502,170,112', '6,572,250', '20,827,516', '5,097,714', '1,061,031', '12,653,618', '3,008', '17,416,812', '11,174,725', '17,787,454', '5,584,350', '18,971,716', '281,908', '2,606,970', '4,50 ...
# [['BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC'], ['BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC'], ['BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC'], ['BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC'], ['BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC', 'BTC', 'LTC', 'NMC', 'PPC', 'NVC', 'TRC', 'DVC', 'FTC', 'FRC', 'CNC', 'MNC', 'IXC', 'BTB', 'BQC']]
