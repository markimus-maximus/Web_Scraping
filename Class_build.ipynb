# %%
import requests
import ast
from bs4 import  BeautifulSoup
import pandas as pd

# %%
#creating empty lists with which to store data later
crypto_name_list = []
crypto_market_cap_list = []
crypto_price_list = []
crypto_circulating_supply_list = []
crypto_ticker_list = []

# %%
#creating a data frame for later
df = pd.DataFrame()

# %%
#create function to scrape data
#example = https://coinmarketcap.com/historical/20220703/'
def crypto_scrape(price_date = '20220703/'):
    #define url and vary depending on the date
    url = 'https://coinmarketcap.com/historical/'+date
    #request webpage
    webpage = requests.get(url)
    #parse the html
    soup = BeautifulSoup(webpage.text, 'html.parser')
    #create a variable for the table rows (tr)
    tr = soup.find_all('tr', attrs={'class':'cmc-table-row'})
    #creating a counter to iterate through first 10 rows (top 10 cryptocurrencies)
    count = 0
    #iterate through the first 10 rows
    for row in tr:
        if count == 10:
            break
        count = count + 1

    #store the name of the coin as a variable by finding td element (column) 
        name_column = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sticky cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--sort-by__name'})
        #find the column within the row and strip the text
        crypto_name = name_column.find('a', attrs={'class': 'cmc-table__column-name--name cmc-link'}).text.strip()
        print(crypto_name)

        #find and createvvariable for market cap
        crypto_market_cap = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__market-cap'}).text.strip()
        print(crypto_market_cap)

        #Find and create variable for the price
        crypto_price = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__price'}).text.strip()
        print(crypto_price)
        #Find and create variable for the circulating supply
        crypto_circulating_supply_and_ticker = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__circulating-supply'}).text.strip()
        print(crypto_circulating_supply_and_ticker)
        #Find and create variable for the circulating supply by splitting the supply+ticker variable
        crypto_ticker = crypto_circulating_supply_and_ticker.split(' ')[1]
        print(crypto_ticker)
        #Find and create variable for the coin ticker
        crypto_circulating_supply = crypto_circulating_supply_and_ticker.split(' ')[0]
        print(crypto_circulating_supply)
        

        #append the data to the associated lists
        crypto_name_list.append(crypto_name)
        crypto_market_cap_list.append(crypto_market_cap)
        crypto_price_list.append(crypto_price)
        crypto_circulating_supply_list.append(crypto_circulating_supply)
        crypto_ticker_list.append(crypto_ticker)

# %% [markdown]
# Don't forget to git push into new branch of github

# %%
#function for returning list of dates (string) between given range (start_date, end_date)
from datetime import timedelta, date

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)
list_dates = []
url_list = []
start_date = date(2013, 4, 28)
end_date = date(2022, 7, 3)
for single_date in daterange(start_date, end_date):

    list = str(single_date.strftime("%Y%m%d/"))
   
    list_dates.append(list)

#Function for concatenating the list of date strings generated in daterange method

def create_cmc_url_list():
    for url_extension in list_dates:
        url_instance = 'https://coinmarketcap.com/historical/'+url_extension
        url_list.append(url_instance)
    print(url_list)

create_cmc_url_list()
# Out:
# ['https://coinmarketcap.com/historical/20130428/', 'https://coinmarketcap.com/historical/20130429/', 'https://coinmarketcap.com/historical/20130430/', 'https://coinmarketcap.com/historical/20130501/', 'https://coinmarketcap.com/historical/20130502/', 'https://coinmarketcap.com/historical/20130503/', 'https://coinmarketcap.com/historical/20130504/', 'https://coinmarketcap.com/historical/20130505/', 'https://coinmarketcap.com/historical/20130506/', 'https://coinmarketcap.com/historical/20130507/', 'https://coinmarketcap.com/historical/20130508/', 'https://coinmarketcap.com/historical/20130509/', 'https://coinmarketcap.com/historical/20130510/', 'https://coinmarketcap.com/historical/20130511/', 'https://coinmarketcap.com/historical/20130512/', 'https://coinmarketcap.com/historical/20130513/', 'https://coinmarketcap.com/historical/20130514/', 'https://coinmarketcap.com/historical/20130515/', 'https://coinmarketcap.com/historical/20130516/', 'https://coinmarketcap.com/historical/20130517/', 'https://coinmarketcap.com/historical/20130518/', 'https://coinmarketcap.com/historical/20130519/', 'https://coinmarketcap.com/historical/20130520/', 'https://coinmarketcap.com/historical/20130521/', 'https://coinmarketcap.com/historical/20130522/', 'https://coinmarketcap.com/historical/20130523/', 'https://coinmarketcap.com/historical/20130524/', 'https://coinmarketcap.com/historical/20130525/', 'https://coinmarketcap.com/historical/20130526/', 'https://coinmarketcap.com/historical/20130527/', 'https://coinmarketcap.com/historical/20130528/', 'https://coinmarketcap.com/historical/20130529/', 'https://coinmarketcap.com/historical/20130530/', 'https://coinmarketcap.com/historical/20130531/', 'https://coinmarketcap.com/historical/20130601/', 'https://coinmarketcap.com/historical/20130602/', 'https://coinmarketcap.com/historical/20130603/', 'https://coinmarketcap.com/historical/20130604/', 'https://coinmarketcap.com/historical/20130605/', 'https://coinmarketcap.com/historical/20130606/', 'https://coinmarketcap.com/historical/20130607/', 'https://coinmarketcap.com/historical/20130608/', 'https://coinmarketcap.com/historical/20130609/', 'https://coinmarketcap.com/historical/20130610/', 'https://coinmarketcap.com/historical/20130611/', 'https://coinmarketcap.com/historical/20130612/', 'https://coinmarketcap.com/historical/20130613/', 'https://coinmarketcap.com/historical/20130614/', 'https://coinmarketcap.com/historical/20130615/', 'https://coinmarketcap.com/historical/20130616/', 'https://coinmarketcap.com/historical/20130617/', 'https://coinmarketcap.com/historical/20130618/', 'https://coinmarketcap.com/historical/20130619/', 'https://coinmarketcap.com/historical/20130620/', 'https://coinmarketcap.com/historical/20130621/', 'https://coinmarketcap.com/historical/20130622/', 'https://coinmarketcap.com/historical/20130623/', 'https://coinmarketcap.com/historical/20130624/', 'https://coinmarketcap.com/historical/20130625/', 'https://coinmarketcap.com/historical/20130626/', 'https://coinmarketcap.com/historical/20130627/', 'https://coinmarketcap.com/historical/20130628/', 'https://coinmarketcap.com/historical/20130629/', 'https://coinmarketcap.com/historical/20130630/', 'https://coinmarketcap.com/historical/20130701/', 'https://coinmarketcap.com/historical/20130702/', 'https://coinmarketcap.com/historical/20130703/', 'https://coinmarketcap.com/historical/20130704/', 'https://coinmarketcap.com/historical/20130705/', 'https://coinmarketcap.com/historical/20130706/', 'https://coinmarketcap.com/historical/20130707/', 'https://coinmarketcap.com/historical/20130708/', 'https://coinmarketcap.com/historical/20130709/', 'https://coinmarketcap.com/historical/20130710/', 'https://coinmarketcap.com/historical/20130711/', 'https://coinmarketcap.com/historical/20130712/', 'https://coinmarketcap.com/historical/20130713/', 'https://coinmarketcap.com/historical/20130714/', 'https://coinmarketcap.com/historical/20130715/', 'https://coinmarketcap.com/historical/20130716/', ...

# %%
#run the function with a nominated date
crypto_scrape(price_date = '20220703/')
# Out:
# Bitcoin
# $368,272,636,367.55
# $19,297.08
# 19,084,375 BTC
# BTC
# 19,084,375
# Ethereum
# $130,354,920,626.22
# $1,073.77
# 121,399,635 ETH
# ETH
# 121,399,635
# Tether
# $66,169,266,578.19
# $0.9991
# 66,230,318,610 USDT *
# USDT
# 66,230,318,610
# USD Coin
# $55,823,349,220.82
# $1.00
# 55,802,605,113 USDC *
# USDC
# 55,802,605,113
# BNB
# $35,754,443,110.53
# $218.98
# 163,276,975 BNB *
# BNB
# 163,276,975
# Binance USD
# $17,534,713,957.66
# $0.9993
# 17,547,224,379 BUSD *
# BUSD
# 17,547,224,379
# XRP
# $15,552,125,745.52
# $0.3217
# 48,343,101,197 XRP *
# XRP
# 48,343,101,197
# Cardano
# $15,377,222,959.95
# $0.4556
# 33,752,565,071 ADA
# ADA
# 33,752,565,071
# Solana
# $11,465,283,748.49
# $33.39
# 343,416,618 SOL *
# SOL
# 343,416,618
# Dogecoin
# $8,912,747,929.92
# $0.06718
# 132,670,764,300 DOGE
# DOGE
# 132,670,764,300

# %%
#store the data in a dataframe to make it structured
df['Name'] = crypto_name_list
df['Market cap'] = crypto_market_cap_list
df['Price'] = crypto_price_list
df['Circulating supply'] = crypto_circulating_supply_list
df['Ticker'] = crypto_ticker_list

#show the data
df
# Out:
#           Name           Market cap       Price Circulating supply Ticker
# 0      Bitcoin  $368,272,636,367.55  $19,297.08         19,084,375    BTC
# 1     Ethereum  $130,354,920,626.22   $1,073.77        121,399,635    ETH
# 2       Tether   $66,169,266,578.19     $0.9991     66,230,318,610   USDT
# 3     USD Coin   $55,823,349,220.82       $1.00     55,802,605,113   USDC
# 4          BNB   $35,754,443,110.53     $218.98        163,276,975    BNB
# 5  Binance USD   $17,534,713,957.66     $0.9993     17,547,224,379   BUSD
# 6          XRP   $15,552,125,745.52     $0.3217     48,343,101,197    XRP
# 7      Cardano   $15,377,222,959.95     $0.4556     33,752,565,071    ADA
# 8       Solana   $11,465,283,748.49      $33.39        343,416,618    SOL
# 9     Dogecoin    $8,912,747,929.92    $0.06718    132,670,764,300   DOGE
